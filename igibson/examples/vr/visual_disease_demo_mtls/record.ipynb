# %%
nn = [
    7.03, 7.60, 10.48, 10.94, 8.82, 14.68, 11.02, 9.13, 7.30, 8.76,
    7.57, 6.16, 12.57, 18.08, 6.96, 7.70, 10.40, 7.44, 6.01, 12.12, 
    10.43, 10.28, 5.10, 10.73, 10.30, 19.10, 8.49, 10.33, 9.72, 11.43,
    9.39, 11.10, 11.71
]

nc1 = [
    8.25, 11.75, 11.02, 15.45, 11.61, 9.18, 10.50, 8.53, 7.56, 10.59,
    6.62, 7.75, 13.57, 10.74, 10.72, 8.18, 6.74, 13.06, 13.37, 10.82, 
    10.54, 10.72, 10.33, 13.78, 10.71, 7.09, 11.04, 9.08, 8.00, 10.63,
    8.35, 8.77, 9.95
]

nc2 = [
    9.88, 20.46, 12.43, 7.22, 7.57, 8.75, 14.77, 9.82, 8.41, 15.51, 
    23.02, 14.71, 14.94, 32.71, 31.69, 14.48, 7.73, 10.10, 13.32, 8.11, 
    13.76, 9.13, 8.07, 8.00, 7.32, 11.62, 13.80, 15.25, 8.05, 16.66,
    11.97, 10.08, 10.68
]

nc3 = [ 
    10.61, 10.45, 17.00, 9.97, 26.43, 10.15, 15.64, 5.95, 9.64, 13.01, 
    12.07, 13.51, 13.05, 11.09, 17.82, 12.24, 12.33, 12.93, 13.25, 15.64,
    9.89, 12.02, 13.28, 10.88, 8.45, 9.34, 10.89, 12.01, 14.71, 42.40, 
    11.24, 16.16, 9.44 
]

na3 = [ 
    7.05, 11.19, 6.82, 12.45, 11.22, 13.29, 10.18, 13.03, 15.40, 13.75,
    14.28, 16.20, 14.87, 10.18, 10.01, 10.03, 11.63, 9.03, 11.82, 12.09, 
    17.14, 11.51, 9.23, 10.55, 8.76, 9.59, 12.38, 16.29, 12.45, 10.60,
    11.66, 13.74, 9.64
]

na2 = [
    10.76, 7.28, 20.14, 14.69, 10.59, 8.36, 11.67, 12.34, 11.45, 8.42,
    9.39, 20.45, 10.44, 10.76, 8.46, 7.23, 9.22, 5.23, 9.76, 8.97,
    7.24, 11.00, 9.01, 12.51, 15.13, 6.65, 10.33, 11.44, 7.94, 11.75, 
    12.18, 6.70, 6.25
]

na4 = [
    8.01, 8.22, 9.98, 9.22, 11.50, 14.28, 11.66, 10.53, 10.74, 18.16,
    15.60, 16.92, 7.60, 17.17, 15.83, 16.30, 8.54, 9.61, 17.33, 9.33,
    17.04, 18.50, 11.46, 10.34, 8.90, 12.17, 20.65, 9.14, 10.03, 23.88,
    9.45, 17.75, 11.43
]

ng2 = [
    8.29, 10.87, 6.77, 10.21, 8.38, 11.32, 11.32, 13.32, 8.23, 12.33, 
    7.17, 8.84, 6.54, 9.45, 12.54, 7.16, 9.27, 9.68, 6.24, 1.71, 
    10.68, 8.09, 10.53, 12.95, 9.79, 12.47, 12.80, 9.48, 6.52, 9.57, 
    12.96, 13.98, 13.46
]

ng3 = [ 
    12.39, 9.56, 11.88, 18.64, 14.98, 11.25, 10.44, 31.29, 6.81, 11.95,
    7.22, 10.32, 5.75, 21.56, 24.34, 12.38, 10.51, 19.47, 9.15, 9.48,
    9.30, 15.94, 9.04, 8.63, 11.23, 9.98, 12.69, 9.80, 11.39, 12.09, 
    10.38, 10.58, 49.00
]

ng4 = [
    9.55, 30.34, 11.63, 13.10, 15.11, 21.96, 13.32, 12.45, 6.92, 5.66,
    12.16, 7.87, 19.52, 16.10, 10.02, 11.71, 14.47, 15.19, 15.70, 13.82,
    11.29, 22.34, 6.49, 9.95, 11.52, 16.92, 34.35, 14.42, 13.52, 13.32, 
    19.73, 25.57, 22.07
]

# %%
pn = [ 
    7.64, 8.27, 6.78, 6.85, 10.84, 9.13, 8.90, 8.59, 14.00, 7.88,
    9.09, 7.57, 7.56, 6.66, 8.29, 8.01, 7.77, 7.65, 11.11, 7.67,
    7.63, 8.13, 7.80, 6.85, 7.29, 6.28, 6.88, 10.98, 6.74, 6.53,
    6.33, 6.69, 8.54, 7.92, 7.07, 6.22, 4.85 
]

pc1 = [
    10.43, 10.76, 8.97, 8.39, 10.28, 11.03, 10.25, 9.53, 8.57, 9.07,
    11.91, 13.64, 11.89, 11.45, 13.40, 9.89, 11.70, 9.17, 11.36, 8.24,
    11.89, 9.19, 14.77, 12.89, 9.94, 10.85, 9.24, 10.30, 11.77, 9.65,
    10.90, 12.42, 8.97
]

pc2 = [ 
    8.78, 12.79, 8.94, 10.37, 12.14, 8.10, 8.60, 9.56, 9.19, 13.99, 
    8.51, 8.82, 11.37, 10.67, 9.76, 15.87, 8.16, 7.66, 9.96, 8.29,
    9.31, 11.06, 9.79, 10.16, 8.30, 12.03, 9.40, 11.40, 12.25, 10.02,
    9.22, 9.19, 10.25
]

pc3 = [
    14.27, 11.97, 11.34, 13.77, 10.52, 10.16, 14.57, 11.09, 12.10, 15.26,
    11.64, 9.26, 11.54, 10.37, 14.00, 12.79, 12.80, 15.40, 11.75, 13.12, 
    9.07, 11.38, 11.66, 12.66, 14.04, 11.59, 9.27, 12.20, 12.00, 11.96,
    10.65, 10.61, 11.23
]

pa2 = [
    11.05, 8.84, 8.06, 9.07, 7.51, 8.38, 7.47, 7.83, 10.22, 8.04,
    9.74, 8.87, 10.62, 9.90, 9.14, 10.71, 8.59, 12.59, 13.70, 8.78,
    11.50, 7.64, 10.44, 9.45, 7.10, 8.67, 11.41, 9.17, 8.57, 8.11,
    9.51, 9.56, 10.15
]

pa3 = [
    11.11, 8.81, 11.70, 11.06, 9.38, 10.45, 19.53, 10.34, 8.19, 7.93, 
    9.54, 8.40, 9.68, 7.29, 12.25, 12.53, 9.85, 9.48, 11.89, 8.43, 
    11.36, 10.02, 11.57, 10.06, 10.27, 7.91, 8.49, 15.77, 9.61, 7.55,
    6.73, 7.49, 8.82
]

pa4 = [ 
    13.22, 17.37, 13.26, 16.95, 14.54, 14.28, 14.70, 15.40, 13.26, 13.67,
    13.98, 13.28, 17.67, 18.64, 12.53, 13.55, 11.97, 12.94, 12.92, 24.79,
    18.60, 10.13, 10.03, 21.73, 11.96, 10.62, 13.43, 12.34, 18.11, 12.45,
    15.32, 11.04, 11.86
]

pg2 = [ 
    9.75, 11.29, 11.03, 11.07, 10.06, 10.86, 9.14, 7.68, 11.15, 10.78, 
    12.43, 7.53, 13.61, 8.78, 9.49, 13.21, 12.16, 8.73, 10.05, 7.93, 
    12.81, 8.10, 11.21, 15.55, 10.05, 7.85, 12.50, 10.75, 11.42, 15.42, 
    10.43, 9.94, 11.75
]

pg3 = [
    8.03, 13.07, 11.52, 14.26, 12.24, 12.28, 9.63, 8.45, 11.53, 12.76,
    10.68, 19.08, 11.32, 13.02, 8.78, 10.90, 9.90, 14.09, 13.78, 15.09, 
    11.53, 10.35, 13.17, 11.50, 11.64, 13.74, 12.28, 10.59, 16.12, 9.25,
    14.01, 11.08, 11.78
]

pg4 = [
    22.14, 20.71, 20.70, 18.00, 26.63, 12.58, 20.49, 21.28, 18.36, 18.51,
    15.05, 26.21, 19.74, 18.30, 16.66, 21.45, 13.94, 15.07, 16.79, 21.00, 
    23.26, 15.70, 18.76, 18.68, 17.61, 15.34, 25.83, 19.73, 17.15, 16.78,
    14.63, 16.18, 18.45
]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
catch_df = pd.DataFrame(
    [['Normal', 85 / .90], ["Cataract", 79/.90, 68/.82, 68/.87], ['AMD', 79/.86, 69/.82, 46/.89], ['Glaucoma', 70/.85, 67/.82, 33/.91]], 
    columns=['VI Type', 'Normal/Early', 'Intermediate', 'Late']
)
pick_df = pd.DataFrame(
    [['Normal',  np.mean(pn)], ["Cataract", np.mean(pc1),  np.mean(pc2),  np.mean(pc3)], ['AMD',  np.mean(pa2),  np.mean(pa3),  np.mean(pa4)], 
    ['Glaucoma',  np.mean(pg2),  np.mean(pg3),  np.mean(pg4)]], 
    columns=['VI Type', 'Normal/Early', 'Intermediate', 'Late']
)
nav_df = pd.DataFrame(
    [['Normal',  np.mean(nn)], ["Cataract", np.mean(nc1),  np.mean(nc2),  np.mean(nc3)], ['AMD',  np.mean(na2),  np.mean(na3),  np.mean(na4)], 
    ['Glaucoma',  np.mean(ng2),  np.mean(ng3),  np.mean(ng4)]], 
    columns=['VI Type', 'Normal/Early', 'Intermediate', 'Late']
)
cn = np.ones(3) *  85 / 90 * 100
cc = np.array([79/90, 68/82, 68/87]) * 100
ca = np.array([79/86, 69/82, 46/89]) * 100
cg = np.array([70/85, 67/82, 33/91]) * 100

# %%
np.mean(np.c_[pc1, pc2, pc3], axis=0)
# Out:
# array([10.68818182, 10.11848485, 12.00121212])

# %%
plt.plot(np.ones(3) * np.mean(pn), label="Normal")
plt.plot(np.mean(np.c_[pc1, pc2, pc3], axis=0), label="Cataract")
plt.plot(np.mean(np.c_[pa2, pa3, pa4], axis=0), label="AMD")
plt.plot(np.mean(np.c_[pg2, pg3, pg4], axis=0), label="Glaucoma")
plt.legend()
plt.xticks(np.arange(3), ['Normal/Early', 'Intermediate', 'Late'])  # Set text labels.
plt.xlabel("Stage of Visual Impairments")
plt.ylabel("Task Completion Time (s)")
plt.title("Task Completion Time for Pick & Place")
plt.savefig("test.png", dpi=100)
plt.show()

# %%
plt.plot(np.ones(3) * np.mean(nn), label="Normal")
plt.plot(np.mean(np.c_[nc1, nc2, nc3], axis=0), label="Cataract")
plt.plot(np.mean(np.c_[na2, na3, na4], axis=0), label="AMD")
plt.plot(np.mean(np.c_[ng2, ng3, ng4], axis=0), label="Glaucoma")
plt.legend()
plt.xticks(np.arange(3), ['Normal/Early', 'Intermediate', 'Late'])  # Set text labels.
plt.xlabel("Stage of Visual Impairments")
plt.ylabel("Task Completion Time (s)")
plt.title("Task Completion Time for Navigation")
plt.savefig("test.png", dpi=100)
plt.show()

# %%
catch_df.plot(x="VI Type", rot=0, kind='bar', ylim=(0, 100), ylabel="SR (%)", title="Success Rate for Catch")
plt.legend(bbox_to_anchor=(0.3, 1.4), loc=2)
plt.show()

# %%
nav_df.plot(x="VI Type", rot=0, kind='bar', ylim=(0, 16), ylabel="time (s)", title="Task Completion Time for Navigation")
plt.legend(bbox_to_anchor=(0.3, 1.4), loc=2)
plt.show()

# %%
pick_df.plot(x="VI Type", rot=0, kind='bar', ylim=(0, 20), ylabel="time (s)", title="Task Completion Time for Pick & Place")
plt.legend(bbox_to_anchor=(0.3, 1.4), loc=2)
plt.show()
