# %%
import os
import numpy as np
import json
import copy
import csv
import scipy
import matplotlib.pyplot as plt 
from statsmodels.regression.linear_model import OLS, WLS
from statsmodels.regression.mixed_linear_model import MixedLM
from statsmodels.tools.tools import add_constant

# %%
data_path = "../../../data/vi_data"
ori_vis = [f"{i}_{j}" for i in ["cataract", "amd", "glaucoma", "presbyopia", "myopia"] for j in [1, 2, 3]] + ["normal_1"]
tasks = ["Catch", "Navigate", "Place", "Slice", "Throw", "Wipe"]
ids = range(1, 11)
save_json = True

# %%
dv_1 = [
    "collision_freq",
    "task_completion_time",
    "throw_distance_from_ball_to_target",
    "num_collisions",
    "total_collision_time",
    "wipe_total_irrevalant_objects_disarrangement",
    "catch_failure_rate",
    "throw_failure_rate",
    "raw_failure_rate",
]

dv_2 = [
    "mean_pupil_dilation",
    "total_body_translation",
    "total_body_rotation",
    "total_fixation_count",
    "total_fixation_duration",
    "total_gaze_movement",
    "total_hmd_rotation",
    "total_hmd_translation",
    "total_left_hand_rotation",
    "total_left_hand_translation",
    "total_right_hand_rotation",
    "total_right_hand_translation",
]

# %%
dv1_data, dv2_data, dr = {}, {}, {}
for dv in dv_1:
    with open(f"{data_path}/json/dv1/{dv}.json", "r") as f:
        dv1_data[dv] = json.load(f)
for dv in dv_2:
    with open(f"{data_path}/json/dv2/{dv}.json", "r") as f:
        dv2_data[dv] = json.load(f)

with open(f"{data_path}/json/subject_ratings.json", "r") as f:
    sr = json.load(f)

# %%
# rename key for catch and throw success rate
for vi in ori_vis:
    dv1_data["catch_failure_rate"][f"catch_{vi}"] = dv1_data["catch_failure_rate"].pop(vi)
    dv1_data["throw_failure_rate"][f"throw_{vi}"] = dv1_data["throw_failure_rate"].pop(vi)
    for id in ids:
        dv1_data["catch_failure_rate"][f"catch_{vi}"][str(id)] = {'0': dv1_data["catch_failure_rate"][f"catch_{vi}"][str(id)]}
        dv1_data["throw_failure_rate"][f"throw_{vi}"][str(id)] = {'0': dv1_data["throw_failure_rate"][f"throw_{vi}"][str(id)]}

# %%
post_processed_ratings = {task: [] for task in tasks}

vis = {
    "Glaucoma": [f"glaucoma_{i}" for i in range(1, 4)], 
    "AMD": [f"amd_{i}" for i in range(1, 4)], 
    "Cataract": [f"cataract_{i}" for i in range(1, 4)], 
    "Myopia": [f"myopia_{i}" for i in range(1, 4)], 
    "Presbyopia": [f"presbyopia_{i}" for i in range(1, 4)], 
    "Normal": ["normal_1"]
}

for task in tasks:
    for vi in vis:
        if vi != "Normal":
            post_processed_ratings[task].append(np.mean([sr[f"{task} [{vi}]"][str(id)] for id in ids]))
        else:
            post_processed_ratings[task].append(1)

# %% [markdown]
# ### Investigating subject rating and 1st DVs

# %%
dv1_data.keys()
# Out:
# dict_keys(['collision_freq', 'task_completion_time', 'throw_distance_from_ball_to_target', 'num_collisions', 'total_collision_time', 'wipe_total_irrevalant_objects_disarrangement', 'catch_failure_rate', 'throw_failure_rate', 'raw_failure_rate'])

# %%
tasks_dv1 = {
    "Slice": "task_completion_time",
    "Throw": "raw_failure_rate",
    "Catch": "catch_failure_rate",
    "Navigate": "total_collision_time",
    "Place": "task_completion_time",
    "Wipe": "task_completion_time"
}

post_processed_dv1 = {task: [] for task in tasks_dv1}

for task in tasks_dv1:
    for vi in vis:
        if task == "Navigate":
            post_processed_dv1[task].append(np.mean(
                [np.mean([np.mean(
                    np.array(list(dv1_data[tasks_dv1[task]][f"{task.lower()}_{v}"][str(id)].values())) / np.array(list(dv1_data["task_completion_time"][f"{task.lower()}_{v}"][str(id)].values()))
                ) for id in ids])
                for v in vis[vi]])
            )
        else:
            post_processed_dv1[task].append(np.mean(
                [np.mean([np.mean(list(dv1_data[tasks_dv1[task]][f"{task.lower()}_{v}"][str(id)].values())) for id in ids]) for v in vis[vi]])
            )

# %%
# for task in tasks_dv1:
#     res = scipy.stats.linregress(post_processed_ratings[task], post_processed_dv1[task])
#     plt.scatter(post_processed_ratings[task], post_processed_dv1[task])
#     plt.plot(range(1, 6), res.intercept + res.slope*range(1, 6), 'orange')
#     if task == "Navigate":
#         plt.title(f"[{task}] collision time ratio vs. subject rating (corr={np.round(res.rvalue, decimals=3)}, p={np.round(res.pvalue, decimals=3)})")
#     plt.title(f"[{task}] {tasks_dv1[task]} vs. subject rating (corr={np.round(res.rvalue, decimals=3)}, p={np.round(res.pvalue, decimals=3)})")
#     plt.xlabel("Subject rating")
#     plt.rcParams["figure.figsize"] = (6, 4)
#     plt.show()

# %% [markdown]
# ## Investigating subject rating and 2nd DVs

# %%
dv2_data.keys()
# Out:
# dict_keys(['mean_pupil_dilation', 'total_body_translation', 'total_body_rotation', 'total_fixation_count', 'total_fixation_duration', 'total_gaze_movement', 'total_hmd_rotation', 'total_hmd_translation', 'total_left_hand_rotation', 'total_left_hand_translation', 'total_right_hand_rotation', 'total_right_hand_translation'])

# %%
tasks_dv2 = {
    "Slice": "total_right_hand_translation",
    "Throw": "total_right_hand_translation",
    "Catch": "total_body_translation",
    "Navigate": "total_hmd_rotation",
    "Place": "total_right_hand_translation",    
    "Wipe": "total_body_translation"
}

post_processed_dv2 = {task: [] for task in tasks_dv2}

for task in tasks_dv2:
    for vi in vis:
        post_processed_dv2[task].append(np.mean(
            [np.mean([np.mean(
                np.array(list(dv2_data[tasks_dv2[task]][f"{task.lower()}_{v}"][str(id)].values())) / np.array(list(dv1_data["task_completion_time"][f"{task.lower()}_{v}"][str(id)].values()))
            ) for id in ids])
            for v in vis[vi][-1:]])
        )

# %%
# for task in tasks_dv2:
#     res = scipy.stats.linregress(post_processed_ratings[task], post_processed_dv2[task])
#     plt.scatter(post_processed_ratings[task], post_processed_dv2[task])
#     plt.plot(range(1, 6), res.intercept + res.slope*range(1, 6), 'orange')
#     plt.title(f"[{task}] {tasks_dv2[task]}_ratio vs. subject rating (corr={np.round(res.rvalue, decimals=3)}, p={np.round(res.pvalue, decimals=3)})")
#     plt.xlabel("Subject rating")
#     plt.rcParams["figure.figsize"] = (6, 4)
#     plt.show()

# %% [markdown]
# ### Multivariate Regression

# %%
standardize = True
normalize = lambda x, y: x / y
average = False
outlier_removal = False

# %%
redv = {}
for dv in [
    "total_gaze_movement",
    "total_body_translation",
    "total_body_rotation",
    "total_hmd_translation",
    "total_hmd_rotation",
    "total_right_hand_translation",
    "total_right_hand_rotation",
    "total_left_hand_translation",
    "total_left_hand_rotation",
]:
    redv[dv] = {}
    for task in tasks:
        redv[dv][task] = {}
        for vi in ori_vis:
            redv[dv][task][vi] = {}
            for id in ids:
                redv[dv][task][vi][id] = np.array(list(dv2_data[dv][f"{task.lower()}_{vi}"][str(id)].values())) / np.array(list(dv1_data["task_completion_time"][f"{task.lower()}_{vi}"][str(id)].values()))

# normalize
for dv in redv:
    for task in tasks:
        for vi in ori_vis:
            for id in ids:
                redv[dv][task][vi][id] = normalize(redv[dv][task][vi][id], np.mean(redv[dv][task]["normal_1"][id]))
                # average
                if average:
                    redv[dv][task][vi][id] = [np.mean(redv[dv][task][vi][id])]

# standardize
if standardize:
    for dv in redv:
        for task in tasks:
            for vi in ori_vis:
                mean, std = np.mean([redv[dv][task][vi][id] for id in ids]), np.std([redv[dv][task][vi][id] for id in ids])
                for id in ids:
                    redv[dv][task][vi][id] -= mean
                    if std:
                        redv[dv][task][vi][id] /= std

# %%
tasks_re = ["Place", "Wipe", "Slice", "Navigate", "Throw", "Catch"]
reiv = {}
for task in tasks_re:
    reiv[tasks_dv1[task]] = {}
for task in tasks_re:
    for vi in ori_vis:
        reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"] = {}
        for id in ids:
            if task == "Throw":
                reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] = -normalize(
                    np.array(list(dv1_data[tasks_dv1[task]][f"{task.lower()}_{vi}"][str(id)].values())), 
                    dv1_data["throw_failure_rate"][f"{task.lower()}_normal_1"][str(id)]['0']
                )
            else:
                reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] = normalize(
                    np.array(list(dv1_data[tasks_dv1[task]][f"{task.lower()}_{vi}"][str(id)].values())), 
                    np.mean(list(dv1_data[tasks_dv1[task]][f"{task.lower()}_normal_1"][str(id)].values()))
                )
            # average
            if average:
                reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] = [np.mean(reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id])]

# %%
models = {task: {vi: {} for vi in ori_vis} for task in tasks_re}
rsq = []
for task in tasks_re:
    for vi in ori_vis[:-1]:
        x, groups = [], []
        for id in ids:
            for trial in range(len(redv[dv][task][vi][id])):
                if task == "Catch" or average:
                    x.append([redv[dv][task][vi][id][trial] for dv in list(redv.keys())[:-2]])
                else:
                    x.append([redv[dv][task][vi][id][trial] for dv in redv])
            groups.append([id] * len(redv[dv][task][vi][id]))
        y = np.array([reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] for id in ids]).flatten()
        x = np.array(x)
        x = add_constant(x)
        groups = np.array(groups).flatten()
        # outlier removal
        if outlier_removal:
            mask = np.abs(y - np.mean(y)) < 2 * np.std(y)
            x = x[mask]
            y = y[mask]
            groups = groups[mask]
        models[task][vi] = OLS(y, x).fit()
        rsq.append(models[task][vi].rsquared_adj)
        print(f"{task}_{vi}", models[task][vi].summary(), "\n" * 10)
print(np.mean(rsq))
# Out:
# Place_cataract_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     2.919
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0553
# Time:                        15:32:33   Log-Likelihood:                -4.5520
# No. Observations:                  20   AIC:                             29.10
# Df Residuals:                      10   BIC:                             39.06
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3306      0.096     13.850      0.000       1.117       1.545
# x1            -0.3930      0.261     -1.506      0.163      -0.974       0.188
# x2            -0.3272      0.332     -0.985      0.348      -1.068       0.413
# x3             0.0081      0.367      0.022      0.983      -0.810       0.826
# x4             0.4328      0.266      1.628      0.134      -0.159       1.025
# x5             0.0147      0.422      0.035      0.973      -0.926       0.955
# x6            -0.0317      0.401     -0.079      0.939      -0.925       0.862
# x7            -0.3308      0.449     -0.737      0.478      -1.330       0.669
# x8             0.0792      0.181      0.439      0.670      -0.323       0.482
# x9             0.3084      0.239      1.290      0.226      -0.224       0.841
# ==============================================================================
# Omnibus:                        0.275   Durbin-Watson:                   1.083
# Prob(Omnibus):                  0.872   Jarque-Bera (JB):                0.452
# Skew:                          -0.073   Prob(JB):                        0.798
# Kurtosis:                       2.278   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_cataract_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     2.189
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.119
# Time:                        15:32:33   Log-Likelihood:                0.63007
# No. Observations:                  20   AIC:                             18.74
# Df Residuals:                      10   BIC:                             28.70
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2372      0.074     16.686      0.000       1.072       1.402
# x1            -0.0245      0.138     -0.178      0.862      -0.332       0.283
# x2             0.3880      0.320      1.213      0.253      -0.324       1.100
# x3             0.2133      0.311      0.686      0.508      -0.479       0.906
# x4            -0.1340      0.332     -0.403      0.695      -0.874       0.606
# x5            -0.2865      0.319     -0.899      0.390      -0.996       0.423
# x6            -0.1786      0.256     -0.697      0.502      -0.750       0.393
# x7             0.0590      0.271      0.218      0.832      -0.544       0.662
# x8            -0.0986      0.123     -0.799      0.443      -0.374       0.176
# x9            -0.1825      0.175     -1.043      0.322      -0.573       0.207
# ==============================================================================
# Omnibus:                        2.085   Durbin-Watson:                   2.209
# Prob(Omnibus):                  0.353   Jarque-Bera (JB):                1.569
# Skew:                           0.512   Prob(JB):                        0.456
# Kurtosis:                       2.087   Cond. No.                         18.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_cataract_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.686
# Model:                            OLS   Adj. R-squared:                  0.404
# Method:                 Least Squares   F-statistic:                     2.429
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0916
# Time:                        15:32:33   Log-Likelihood:                -21.848
# No. Observations:                  20   AIC:                             63.70
# Df Residuals:                      10   BIC:                             73.65
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6639      0.228     11.677      0.000       2.156       3.172
# x1             0.0002      0.281      0.001      0.999      -0.626       0.626
# x2            -0.7362      0.305     -2.412      0.037      -1.416      -0.056
# x3            -0.0108      0.543     -0.020      0.985      -1.221       1.199
# x4             0.4729      0.401      1.180      0.265      -0.420       1.366
# x5            -0.0384      0.574     -0.067      0.948      -1.317       1.240
# x6            -0.4058      0.359     -1.130      0.285      -1.206       0.394
# x7            -0.4344      0.384     -1.131      0.284      -1.290       0.421
# x8             0.1790      0.391      0.458      0.657      -0.692       1.050
# x9             0.0350      0.353      0.099      0.923      -0.752       0.822
# ==============================================================================
# Omnibus:                        1.381   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.501   Jarque-Bera (JB):                0.424
# Skew:                           0.327   Prob(JB):                        0.809
# Kurtosis:                       3.284   Cond. No.                         5.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_amd_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     2.111
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.130
# Time:                        15:32:33   Log-Likelihood:                -1.1325
# No. Observations:                  20   AIC:                             22.26
# Df Residuals:                      10   BIC:                             32.22
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0609      0.081     13.101      0.000       0.880       1.241
# x1            -0.1332      0.095     -1.408      0.190      -0.344       0.078
# x2            -0.1911      0.404     -0.473      0.646      -1.091       0.709
# x3             0.4737      0.530      0.894      0.392      -0.707       1.655
# x4             0.4615      0.455      1.013      0.335      -0.553       1.476
# x5            -0.4120      0.626     -0.658      0.526      -1.808       0.984
# x6            -0.1737      0.319     -0.545      0.598      -0.883       0.536
# x7            -0.2019      0.252     -0.801      0.442      -0.763       0.360
# x8            -0.0917      0.160     -0.573      0.580      -0.449       0.265
# x9            -0.0670      0.209     -0.321      0.755      -0.533       0.399
# ==============================================================================
# Omnibus:                        0.463   Durbin-Watson:                   1.388
# Prob(Omnibus):                  0.793   Jarque-Bera (JB):                0.458
# Skew:                           0.305   Prob(JB):                        0.795
# Kurtosis:                       2.579   Cond. No.                         24.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_amd_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     2.295
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.106
# Time:                        15:32:33   Log-Likelihood:                 10.711
# No. Observations:                  20   AIC:                            -1.421
# Df Residuals:                      10   BIC:                             8.536
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2049      0.045     26.900      0.000       1.105       1.305
# x1             0.0332      0.056      0.591      0.567      -0.092       0.158
# x2             0.0824      0.114      0.720      0.488      -0.172       0.337
# x3             0.0388      0.111      0.350      0.734      -0.208       0.286
# x4            -0.0040      0.141     -0.028      0.978      -0.319       0.311
# x5            -0.0287      0.172     -0.167      0.871      -0.412       0.354
# x6            -0.1935      0.146     -1.327      0.214      -0.518       0.131
# x7             0.2181      0.167      1.306      0.221      -0.154       0.590
# x8            -0.1199      0.080     -1.491      0.167      -0.299       0.059
# x9            -0.1158      0.091     -1.275      0.231      -0.318       0.087
# ==============================================================================
# Omnibus:                        0.815   Durbin-Watson:                   2.556
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.066
# Skew:                          -0.058   Prob(JB):                        0.968
# Kurtosis:                       3.256   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_amd_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.693
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     2.508
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0842
# Time:                        15:32:33   Log-Likelihood:                -23.733
# No. Observations:                  20   AIC:                             67.47
# Df Residuals:                      10   BIC:                             77.42
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5877      0.251     22.290      0.000       5.029       6.146
# x1            -1.0936      0.556     -1.965      0.078      -2.334       0.146
# x2             2.0921      1.008      2.076      0.065      -0.154       4.338
# x3            -1.5777      1.490     -1.059      0.315      -4.898       1.742
# x4            -2.1528      1.763     -1.221      0.250      -6.082       1.776
# x5             3.2835      2.448      1.341      0.210      -2.171       8.738
# x6            -0.4010      0.846     -0.474      0.646      -2.286       1.484
# x7             1.4508      0.710      2.044      0.068      -0.131       3.032
# x8             1.1477      0.425      2.703      0.022       0.202       2.094
# x9            -2.1944      1.080     -2.031      0.070      -4.602       0.213
# ==============================================================================
# Omnibus:                        0.503   Durbin-Watson:                   2.498
# Prob(Omnibus):                  0.778   Jarque-Bera (JB):                0.122
# Skew:                           0.191   Prob(JB):                        0.941
# Kurtosis:                       2.966   Cond. No.                         32.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_glaucoma_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                     3.608
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0290
# Time:                        15:32:33   Log-Likelihood:                 12.444
# No. Observations:                  20   AIC:                            -4.888
# Df Residuals:                      10   BIC:                             5.070
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0925      0.041     26.599      0.000       1.001       1.184
# x1             0.0079      0.068      0.116      0.910      -0.143       0.159
# x2             0.2273      0.110      2.057      0.067      -0.019       0.473
# x3             0.0882      0.196      0.449      0.663      -0.349       0.525
# x4            -0.0714      0.107     -0.666      0.521      -0.310       0.168
# x5             0.1953      0.136      1.434      0.182      -0.108       0.499
# x6            -0.1812      0.091     -1.981      0.076      -0.385       0.023
# x7            -0.1221      0.086     -1.421      0.186      -0.313       0.069
# x8             0.0999      0.083      1.199      0.258      -0.086       0.286
# x9            -0.4783      0.206     -2.324      0.042      -0.937      -0.020
# ==============================================================================
# Omnibus:                        1.207   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.547   Jarque-Bera (JB):                0.823
# Skew:                          -0.047   Prob(JB):                        0.663
# Kurtosis:                       2.010   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_glaucoma_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     1.552
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.251
# Time:                        15:32:33   Log-Likelihood:                 1.5607
# No. Observations:                  20   AIC:                             16.88
# Df Residuals:                      10   BIC:                             26.84
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1783      0.071     16.649      0.000       1.021       1.336
# x1            -0.0901      0.089     -1.012      0.335      -0.288       0.108
# x2             0.0454      0.160      0.283      0.783      -0.312       0.403
# x3             0.1561      0.242      0.644      0.534      -0.384       0.696
# x4             0.0629      0.135      0.465      0.652      -0.238       0.364
# x5            -0.1106      0.166     -0.668      0.519      -0.480       0.258
# x6            -0.0206      0.191     -0.108      0.916      -0.447       0.405
# x7            -0.1338      0.154     -0.870      0.405      -0.477       0.209
# x8            -0.1900      0.153     -1.241      0.243      -0.531       0.151
# x9            -0.0857      0.166     -0.517      0.616      -0.455       0.283
# ==============================================================================
# Omnibus:                        1.709   Durbin-Watson:                   1.720
# Prob(Omnibus):                  0.426   Jarque-Bera (JB):                1.273
# Skew:                           0.407   Prob(JB):                        0.529
# Kurtosis:                       2.070   Cond. No.                         9.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_glaucoma_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     2.931
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0546
# Time:                        15:32:33   Log-Likelihood:                -22.965
# No. Observations:                  20   AIC:                             65.93
# Df Residuals:                      10   BIC:                             75.89
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8802      0.241     16.085      0.000       3.343       4.418
# x1            -0.1185      0.277     -0.428      0.678      -0.736       0.499
# x2            -0.2575      0.474     -0.543      0.599      -1.314       0.799
# x3             1.3992      0.674      2.077      0.065      -0.102       2.900
# x4            -0.2394      0.519     -0.461      0.654      -1.396       0.917
# x5            -0.2090      0.455     -0.459      0.656      -1.223       0.805
# x6            -0.8303      0.739     -1.123      0.288      -2.477       0.817
# x7             0.5899      0.732      0.806      0.439      -1.040       2.220
# x8            -1.3618      0.382     -3.563      0.005      -2.213      -0.510
# x9             0.5816      0.621      0.936      0.371      -0.803       1.966
# ==============================================================================
# Omnibus:                        1.380   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.502   Jarque-Bera (JB):                1.092
# Skew:                          -0.356   Prob(JB):                        0.579
# Kurtosis:                       2.104   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_presbyopia_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     3.081
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0471
# Time:                        15:32:33   Log-Likelihood:                 7.5780
# No. Observations:                  20   AIC:                             4.844
# Df Residuals:                      10   BIC:                             14.80
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1753      0.052     22.436      0.000       1.059       1.292
# x1             0.0154      0.080      0.192      0.851      -0.163       0.194
# x2             0.0310      0.112      0.276      0.788      -0.219       0.281
# x3             0.2671      0.142      1.876      0.090      -0.050       0.584
# x4             0.1080      0.141      0.766      0.461      -0.206       0.422
# x5            -0.3981      0.174     -2.289      0.045      -0.786      -0.011
# x6            -0.1955      0.176     -1.109      0.293      -0.588       0.197
# x7            -0.0262      0.137     -0.191      0.852      -0.332       0.279
# x8             0.1167      0.165      0.708      0.495      -0.250       0.484
# x9             0.0136      0.185      0.073      0.943      -0.399       0.426
# ==============================================================================
# Omnibus:                        1.877   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.391   Jarque-Bera (JB):                1.028
# Skew:                           0.555   Prob(JB):                        0.598
# Kurtosis:                       3.027   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_presbyopia_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     4.436
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0146
# Time:                        15:32:33   Log-Likelihood:                 11.530
# No. Observations:                  20   AIC:                            -3.060
# Df Residuals:                      10   BIC:                             6.897
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0446      0.043     24.298      0.000       0.949       1.140
# x1             0.0366      0.170      0.215      0.834      -0.342       0.416
# x2            -0.0627      0.064     -0.980      0.350      -0.205       0.080
# x3             0.5403      0.353      1.531      0.157      -0.246       1.327
# x4             0.0617      0.100      0.614      0.553      -0.162       0.286
# x5            -0.4622      0.497     -0.930      0.374      -1.569       0.645
# x6            -0.0790      0.192     -0.412      0.689      -0.506       0.348
# x7            -0.0494      0.142     -0.347      0.736      -0.366       0.268
# x8             0.0951      0.082      1.166      0.271      -0.087       0.277
# x9            -0.2592      0.114     -2.267      0.047      -0.514      -0.004
# ==============================================================================
# Omnibus:                        3.362   Durbin-Watson:                   2.338
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                1.328
# Skew:                          -0.121   Prob(JB):                        0.515
# Kurtosis:                       1.761   Cond. No.                         33.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_presbyopia_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     5.500
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00678
# Time:                        15:32:33   Log-Likelihood:                 15.229
# No. Observations:                  20   AIC:                            -10.46
# Df Residuals:                      10   BIC:                           -0.4999
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0296      0.036     28.812      0.000       0.950       1.109
# x1             0.0639      0.090      0.713      0.492      -0.136       0.263
# x2            -0.0259      0.055     -0.468      0.650      -0.149       0.097
# x3            -0.1076      0.086     -1.258      0.237      -0.298       0.083
# x4             0.0906      0.088      1.030      0.327      -0.105       0.286
# x5            -0.0462      0.188     -0.246      0.811      -0.465       0.373
# x6            -0.2463      0.111     -2.215      0.051      -0.494       0.001
# x7            -0.1157      0.071     -1.640      0.132      -0.273       0.041
# x8            -0.0543      0.050     -1.094      0.299      -0.165       0.056
# x9             0.1821      0.124      1.464      0.174      -0.095       0.459
# ==============================================================================
# Omnibus:                        0.135   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.935   Jarque-Bera (JB):                0.313
# Skew:                           0.147   Prob(JB):                        0.855
# Kurtosis:                       2.463   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_myopia_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     3.699
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0268
# Time:                        15:32:33   Log-Likelihood:                 8.8750
# No. Observations:                  20   AIC:                             2.250
# Df Residuals:                      10   BIC:                             12.21
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0465      0.049     21.316      0.000       0.937       1.156
# x1            -0.0408      0.097     -0.419      0.684      -0.258       0.176
# x2            -0.1119      0.115     -0.976      0.352      -0.367       0.144
# x3             0.4505      0.236      1.913      0.085      -0.074       0.975
# x4             0.2566      0.242      1.059      0.314      -0.283       0.797
# x5            -0.4676      0.268     -1.743      0.112      -1.065       0.130
# x6            -0.2179      0.132     -1.651      0.130      -0.512       0.076
# x7            -0.0901      0.149     -0.603      0.560      -0.423       0.243
# x8             0.0311      0.105      0.296      0.773      -0.203       0.265
# x9            -0.0901      0.136     -0.661      0.524      -0.394       0.214
# ==============================================================================
# Omnibus:                        1.927   Durbin-Watson:                   1.561
# Prob(Omnibus):                  0.382   Jarque-Bera (JB):                1.593
# Skew:                           0.637   Prob(JB):                        0.451
# Kurtosis:                       2.463   Cond. No.                         19.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_myopia_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     3.438
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0338
# Time:                        15:32:33   Log-Likelihood:                -22.873
# No. Observations:                  20   AIC:                             65.75
# Df Residuals:                      10   BIC:                             75.70
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2035      0.240      9.176      0.000       1.668       2.739
# x1             0.7305      0.429      1.703      0.119      -0.225       1.686
# x2            -0.5143      0.416     -1.235      0.245      -1.442       0.413
# x3             0.4127      0.880      0.469      0.649      -1.547       2.373
# x4            -0.0963      0.439     -0.219      0.831      -1.075       0.882
# x5            -0.7288      0.900     -0.810      0.437      -2.735       1.277
# x6            -0.4047      0.595     -0.680      0.512      -1.731       0.922
# x7             1.7677      0.649      2.723      0.021       0.321       3.214
# x8             0.1312      0.418      0.314      0.760      -0.800       1.063
# x9             0.2679      0.498      0.537      0.603      -0.843       1.378
# ==============================================================================
# Omnibus:                        1.513   Durbin-Watson:                   2.289
# Prob(Omnibus):                  0.469   Jarque-Bera (JB):                1.119
# Skew:                           0.557   Prob(JB):                        0.571
# Kurtosis:                       2.681   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_myopia_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     2.153
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.124
# Time:                        15:32:33   Log-Likelihood:                -29.193
# No. Observations:                  20   AIC:                             78.39
# Df Residuals:                      10   BIC:                             88.34
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2762      0.329      9.947      0.000       2.542       4.010
# x1            -0.4815      0.565     -0.852      0.414      -1.741       0.778
# x2             1.0589      0.657      1.612      0.138      -0.405       2.522
# x3             1.2860      0.974      1.320      0.216      -0.885       3.457
# x4            -2.8585      1.440     -1.985      0.075      -6.067       0.350
# x5             1.3001      1.110      1.171      0.269      -1.174       3.774
# x6            -0.8370      0.607     -1.380      0.198      -2.189       0.515
# x7             0.8706      0.560      1.555      0.151      -0.377       2.118
# x8             0.6837      0.669      1.021      0.331      -0.808       2.175
# x9            -1.2198      0.820     -1.488      0.168      -3.046       0.607
# ==============================================================================
# Omnibus:                        0.816   Durbin-Watson:                   2.483
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.820
# Skew:                           0.362   Prob(JB):                        0.664
# Kurtosis:                       2.322   Cond. No.                         11.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_cataract_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     4.926
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           0.000182
# Time:                        15:32:33   Log-Likelihood:                -24.923
# No. Observations:                  50   AIC:                             69.85
# Df Residuals:                      40   BIC:                             88.97
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3241      0.063     21.024      0.000       1.197       1.451
# x1            -0.0750      0.087     -0.864      0.393      -0.251       0.101
# x2            -0.0958      0.120     -0.798      0.430      -0.338       0.147
# x3            -0.0500      0.175     -0.285      0.777      -0.405       0.305
# x4             0.1891      0.087      2.184      0.035       0.014       0.364
# x5            -0.0535      0.164     -0.327      0.746      -0.385       0.278
# x6            -0.6625      0.169     -3.927      0.000      -1.003      -0.321
# x7             0.4057      0.131      3.092      0.004       0.141       0.671
# x8             0.0050      0.139      0.036      0.972      -0.276       0.286
# x9             0.1042      0.148      0.706      0.484      -0.194       0.402
# ==============================================================================
# Omnibus:                       21.975   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.100
# Skew:                           1.377   Prob(JB):                     1.45e-08
# Kurtosis:                       6.121   Cond. No.                         8.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_cataract_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     2.044
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0592
# Time:                        15:32:33   Log-Likelihood:                -37.797
# No. Observations:                  50   AIC:                             95.59
# Df Residuals:                      40   BIC:                             114.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3513      0.081     16.585      0.000       1.187       1.516
# x1            -0.1280      0.117     -1.097      0.279      -0.364       0.108
# x2            -0.1736      0.242     -0.718      0.477      -0.662       0.315
# x3            -0.0479      0.212     -0.226      0.822      -0.475       0.380
# x4             0.5122      0.275      1.860      0.070      -0.044       1.069
# x5             0.0785      0.197      0.399      0.692      -0.319       0.476
# x6            -0.0780      0.238     -0.327      0.745      -0.559       0.403
# x7            -0.1317      0.178     -0.741      0.463      -0.491       0.227
# x8            -0.2492      0.185     -1.347      0.186      -0.623       0.125
# x9            -0.0410      0.139     -0.295      0.769      -0.322       0.240
# ==============================================================================
# Omnibus:                       40.371   Durbin-Watson:                   1.522
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.634
# Skew:                           2.240   Prob(JB):                     2.35e-27
# Kurtosis:                       9.229   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_cataract_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     1.688
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.124
# Time:                        15:32:33   Log-Likelihood:                -61.222
# No. Observations:                  50   AIC:                             142.4
# Df Residuals:                      40   BIC:                             161.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7666      0.130     13.572      0.000       1.504       2.030
# x1            -0.2149      0.194     -1.108      0.274      -0.607       0.177
# x2             0.1352      0.267      0.506      0.615      -0.404       0.675
# x3            -0.5008      0.380     -1.318      0.195      -1.269       0.267
# x4            -0.1133      0.178     -0.637      0.528      -0.473       0.246
# x5             0.5201      0.339      1.536      0.132      -0.164       1.205
# x6            -0.4556      0.298     -1.527      0.135      -1.058       0.147
# x7             0.1592      0.279      0.571      0.571      -0.405       0.723
# x8             0.0258      0.274      0.094      0.925      -0.527       0.579
# x9            -0.1687      0.322     -0.524      0.603      -0.819       0.482
# ==============================================================================
# Omnibus:                       45.808   Durbin-Watson:                   1.562
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.140
# Skew:                           2.462   Prob(JB):                     5.65e-39
# Kurtosis:                      10.765   Cond. No.                         9.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_amd_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     7.189
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           4.02e-06
# Time:                        15:32:33   Log-Likelihood:                -12.234
# No. Observations:                  50   AIC:                             44.47
# Df Residuals:                      40   BIC:                             63.59
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2957      0.049     26.516      0.000       1.197       1.394
# x1             0.0368      0.061      0.608      0.547      -0.086       0.159
# x2             0.0045      0.108      0.042      0.967      -0.214       0.223
# x3            -0.1218      0.158     -0.769      0.447      -0.442       0.198
# x4             0.0489      0.088      0.555      0.582      -0.129       0.227
# x5             0.1683      0.165      1.021      0.314      -0.165       0.502
# x6            -0.4120      0.117     -3.521      0.001      -0.648      -0.176
# x7            -0.0411      0.110     -0.375      0.709      -0.263       0.180
# x8            -0.0030      0.108     -0.028      0.978      -0.222       0.216
# x9             0.0041      0.130      0.032      0.975      -0.259       0.267
# ==============================================================================
# Omnibus:                        7.488   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.062
# Skew:                           0.644   Prob(JB):                       0.0293
# Kurtosis:                       4.316   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_amd_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     3.419
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00334
# ...
# x5            -0.5087      0.208     -2.442      0.135      -1.405       0.388
# x6             0.5441      0.147      3.711      0.066      -0.087       1.175
# x7            -0.7815      0.223     -3.500      0.073      -1.742       0.179
# ==============================================================================
# Omnibus:                        1.362   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                0.971
# Skew:                          -0.552   Prob(JB):                        0.615
# Kurtosis:                       1.945   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_presbyopia_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                 -0.077
# Method:                 Least Squares   F-statistic:                    0.9077
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.616
# Time:                        15:32:33   Log-Likelihood:                -2.9153
# No. Observations:                  10   AIC:                             21.83
# Df Residuals:                       2   BIC:                             24.25
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8250      0.229      3.602      0.069      -0.160       1.810
# x1            -0.2611      0.747     -0.349      0.760      -3.476       2.954
# x2            -0.4240      1.208     -0.351      0.759      -5.624       4.776
# x3            -0.4121      0.578     -0.713      0.550      -2.900       2.076
# x4             0.7363      1.411      0.522      0.654      -5.336       6.808
# x5             0.0353      1.014      0.035      0.975      -4.328       4.399
# x6             0.2320      1.352      0.172      0.880      -5.585       6.049
# x7             0.2704      0.659      0.411      0.721      -2.563       3.104
# ==============================================================================
# Omnibus:                        1.813   Durbin-Watson:                   2.388
# Prob(Omnibus):                  0.404   Jarque-Bera (JB):                0.838
# Skew:                           0.207   Prob(JB):                        0.658
# Kurtosis:                       1.644   Cond. No.                         15.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_presbyopia_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     4.149
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.208
# Time:                        15:32:33   Log-Likelihood:                 2.6490
# No. Observations:                  10   AIC:                             10.70
# Df Residuals:                       2   BIC:                             13.12
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0500      0.131      7.998      0.015       0.485       1.615
# x1             0.1012      0.236      0.429      0.710      -0.913       1.116
# x2            -0.6701      0.552     -1.213      0.349      -3.047       1.707
# x3             0.5093      0.207      2.464      0.133      -0.380       1.399
# x4             1.0688      0.468      2.281      0.150      -0.947       3.085
# x5            -0.7738      0.620     -1.248      0.338      -3.441       1.894
# x6             0.2485      0.209      1.187      0.357      -0.652       1.149
# x7             0.1837      0.465      0.395      0.731      -1.817       2.185
# ==============================================================================
# Omnibus:                        0.290   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.865   Jarque-Bera (JB):                0.246
# Skew:                          -0.276   Prob(JB):                        0.884
# Kurtosis:                       2.467   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_myopia_1                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     4.713
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.186
# Time:                        15:32:33   Log-Likelihood:                -1.5196
# No. Observations:                  10   AIC:                             19.04
# Df Residuals:                       2   BIC:                             21.46
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4250      0.199      7.154      0.019       0.568       2.282
# x1            -0.3262      0.324     -1.006      0.420      -1.722       1.069
# x2            -1.6173      0.634     -2.551      0.125      -4.345       1.111
# x3            -0.3786      0.769     -0.492      0.671      -3.688       2.931
# x4             3.0593      1.916      1.597      0.251      -5.183      11.302
# x5            -1.2419      0.968     -1.283      0.328      -5.407       2.923
# x6             1.3239      0.532      2.488      0.131      -0.966       3.614
# x7            -1.1091      0.642     -1.727      0.226      -3.872       1.653
# ==============================================================================
# Omnibus:                        4.549   Durbin-Watson:                   2.934
# Prob(Omnibus):                  0.103   Jarque-Bera (JB):                1.978
# Skew:                          -1.086   Prob(JB):                        0.372
# Kurtosis:                       3.158   Cond. No.                         24.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_myopia_2                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     3.856
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.221
# Time:                        15:32:33   Log-Likelihood:               0.081165
# No. Observations:                  10   AIC:                             15.84
# Df Residuals:                       2   BIC:                             18.26
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0500      0.170      6.187      0.025       0.320       1.780
# x1             0.7170      0.305      2.354      0.143      -0.594       2.028
# x2            -0.3883      0.400     -0.971      0.434      -2.109       1.332
# x3            -0.8328      0.480     -1.735      0.225      -2.898       1.233
# x4             1.5872      0.571      2.779      0.109      -0.870       4.044
# x5            -0.8799      0.515     -1.709      0.230      -3.096       1.336
# x6             0.8380      0.331      2.535      0.127      -0.584       2.260
# x7            -0.1440      0.480     -0.300      0.792      -2.209       1.921
# ==============================================================================
# Omnibus:                        1.306   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.521   Jarque-Bera (JB):                0.863
# Skew:                          -0.423   Prob(JB):                        0.650
# Kurtosis:                       1.836   Cond. No.                         8.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_myopia_3                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     3.402
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.246
# Time:                        15:32:33   Log-Likelihood:                -2.5392
# No. Observations:                  10   AIC:                             21.08
# Df Residuals:                       2   BIC:                             23.50
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7750      0.221      8.048      0.015       0.826       2.724
# x1            -0.7730      0.426     -1.815      0.211      -2.606       1.060
# x2            -0.8187      0.690     -1.187      0.357      -3.786       2.148
# x3             1.3481      0.924      1.459      0.282      -2.629       5.325
# x4             1.2101      0.947      1.277      0.330      -2.866       5.286
# x5            -2.4854      0.760     -3.272      0.082      -5.754       0.783
# x6            -0.8994      0.533     -1.688      0.233      -3.192       1.393
# x7             1.1627      0.683      1.701      0.231      -1.778       4.103
# ==============================================================================
# Omnibus:                        5.927   Durbin-Watson:                   2.203
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                2.300
# Skew:                          -1.128   Prob(JB):                        0.317
# Kurtosis:                       3.653   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# 0.27147711394206
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# ### Aggregate across VI categories

# %%
rsq = []
models = {task: None for task in tasks_re}
for task in tasks_re:
    for v in vis:
        x, y, groups = [], [], []
        for vi in vis[v]:
            for id in ids:
                for trial in range(len(redv[dv][task][vi][id])):
                    x.append([redv[dv][task][vi][id][trial] for dv in redv])
                groups.extend([id] * len(redv[dv][task][vi][id]))
        y = np.hstack([np.array([reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] for id in ids]).flatten() for vi in vis[v]])
        x = np.array(x)
        x = add_constant(x)
        groups = np.array(groups).flatten()
        # outlier removal
        if outlier_removal:
            mask = np.abs(y - np.mean(y)) < 2 * np.std(y)
            x = x[mask]
            y = y[mask]
            groups = groups[mask]
        models[task] = OLS(y, x, missing='drop').fit()
        rsq.append(models[task].rsquared_adj)
        print(f"{task}_{v}", models[task].summary(), "\n" * 10)
print(np.mean(rsq))
# Out:
# Place_Glaucoma                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                 -0.087
# Method:                 Least Squares   F-statistic:                    0.4745
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.885
# Time:                        15:32:34   Log-Likelihood:                -109.50
# No. Observations:                  60   AIC:                             239.0
# Df Residuals:                      50   BIC:                             259.9
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0503      0.212      9.660      0.000       1.624       2.477
# x1             0.0325      0.236      0.138      0.891      -0.441       0.506
# x2             0.1171      0.364      0.322      0.749      -0.613       0.847
# x3             0.4317      0.609      0.709      0.482      -0.792       1.655
# x4             0.1548      0.354      0.437      0.664      -0.556       0.866
# x5            -0.3239      0.440     -0.736      0.465      -1.208       0.560
# x6            -0.1543      0.435     -0.355      0.724      -1.028       0.719
# x7            -0.0446      0.428     -0.104      0.917      -0.904       0.815
# x8            -0.3234      0.304     -1.063      0.293      -0.934       0.287
# x9            -0.0358      0.514     -0.070      0.945      -1.069       0.997
# ==============================================================================
# Omnibus:                       16.393   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.920
# Skew:                           1.286   Prob(JB):                     7.79e-05
# Kurtosis:                       3.977   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_AMD                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                 -0.138
# Method:                 Least Squares   F-statistic:                    0.2075
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.992
# Time:                        15:32:34   Log-Likelihood:                -133.38
# No. Observations:                  60   AIC:                             286.8
# Df Residuals:                      50   BIC:                             307.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6178      0.316      8.284      0.000       1.983       3.253
# x1            -0.1405      0.375     -0.375      0.709      -0.893       0.612
# x2             0.4039      0.703      0.574      0.568      -1.008       1.816
# x3            -0.0102      0.843     -0.012      0.990      -1.704       1.683
# x4            -0.4153      0.992     -0.419      0.677      -2.407       1.577
# x5             0.5521      1.142      0.483      0.631      -1.742       2.846
# x6            -0.6619      0.807     -0.821      0.416      -2.282       0.958
# x7             0.4546      0.727      0.625      0.535      -1.006       1.915
# x8             0.3036      0.411      0.738      0.464      -0.523       1.130
# x9            -0.2657      0.619     -0.429      0.670      -1.509       0.978
# ==============================================================================
# Omnibus:                       10.047   Durbin-Watson:                   0.321
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.464
# Skew:                           0.898   Prob(JB):                      0.00881
# Kurtosis:                       2.251   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_Cataract                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     2.323
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0285
# Time:                        15:32:34   Log-Likelihood:                -78.673
# No. Observations:                  60   AIC:                             177.3
# Df Residuals:                      50   BIC:                             198.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7439      0.127     13.734      0.000       1.489       1.999
# x1            -0.1083      0.169     -0.640      0.525      -0.448       0.232
# x2            -0.4446      0.233     -1.906      0.062      -0.913       0.024
# x3            -0.0190      0.332     -0.057      0.954      -0.686       0.648
# x4             0.5217      0.224      2.330      0.024       0.072       0.971
# x5             0.0373      0.321      0.116      0.908      -0.607       0.682
# x6            -0.2847      0.254     -1.119      0.268      -0.796       0.226
# x7            -0.1740      0.255     -0.682      0.498      -0.686       0.338
# x8             0.0275      0.160      0.172      0.864      -0.294       0.349
# x9             0.0878      0.202      0.434      0.666      -0.319       0.494
# ==============================================================================
# Omnibus:                       15.541   Durbin-Watson:                   0.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.065
# Skew:                           1.115   Prob(JB):                     0.000119
# Kurtosis:                       4.502   Cond. No.                         7.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_Myopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     1.584
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.146
# Time:                        15:32:34   Log-Likelihood:                -107.55
# No. Observations:                  60   AIC:                             235.1
# Df Residuals:                      50   BIC:                             256.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1754      0.205     10.587      0.000       1.763       2.588
# x1            -0.3812      0.247     -1.541      0.130      -0.878       0.116
# x2             0.2758      0.355      0.777      0.441      -0.437       0.988
# x3             0.5013      0.630      0.796      0.430      -0.764       1.766
# x4            -0.9346      0.383     -2.438      0.018      -1.705      -0.165
# x5             0.2103      0.582      0.362      0.719      -0.958       1.379
# x6            -0.3386      0.378     -0.896      0.374      -1.097       0.420
# x7             0.5293      0.376      1.409      0.165      -0.225       1.284
# x8            -0.0997      0.269     -0.370      0.713      -0.640       0.441
# x9             0.0059      0.421      0.014      0.989      -0.839       0.851
# ==============================================================================
# Omnibus:                       10.275   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.127
# Skew:                           0.963   Prob(JB):                      0.00632
# Kurtosis:                       3.586   Cond. No.                         8.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_Presbyopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     8.214
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           2.28e-07
# Time:                        15:32:34   Log-Likelihood:                 12.748
# No. Observations:                  60   AIC:                            -5.496
# Df Residuals:                      50   BIC:                             15.45
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0832      0.028     39.146      0.000       1.028       1.139
# x1            -0.0423      0.046     -0.916      0.364      -0.135       0.050
# x2            -0.0339      0.038     -0.893      0.376      -0.110       0.042
# x3             0.1257      0.072      1.751      0.086      -0.018       0.270
# x4             0.1303      0.056      2.333      0.024       0.018       0.243
# x5            -0.1251      0.103     -1.219      0.229      -0.331       0.081
# x6            -0.1906      0.073     -2.612      0.012      -0.337      -0.044
# x7            -0.0615      0.056     -1.095      0.279      -0.174       0.051
# x8             0.0481      0.042      1.152      0.255      -0.036       0.132
# x9            -0.0443      0.061     -0.722      0.474      -0.168       0.079
# ==============================================================================
# Omnibus:                        4.114   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.128   Jarque-Bera (JB):                3.257
# Skew:                           0.546   Prob(JB):                        0.196
# Kurtosis:                       3.329   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Place_Normal                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     25.44
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           9.69e-06
# Time:                        15:32:34   Log-Likelihood:                 50.595
# No. Observations:                  20   AIC:                            -81.19
# Df Residuals:                      10   BIC:                            -71.23
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0000      0.006    164.015      0.000       0.986       1.014
# x1             0.0439      0.017      2.609      0.026       0.006       0.081
# x2            -0.0181      0.012     -1.468      0.173      -0.046       0.009
# x3             0.0170      0.036      0.470      0.649      -0.064       0.098
# x4             0.1062      0.023      4.650      0.001       0.055       0.157
# x5            -0.1183      0.034     -3.449      0.006      -0.195      -0.042
# x6            -0.0851      0.012     -6.820      0.000      -0.113      -0.057
# x7            -0.0182      0.012     -1.571      0.147      -0.044       0.008
# x8            -0.1579      0.031     -5.036      0.001      -0.228      -0.088
# x9             0.1414      0.024      6.016      0.000       0.089       0.194
# ==============================================================================
# Omnibus:                        2.679   Durbin-Watson:                   2.708
# Prob(Omnibus):                  0.262   Jarque-Bera (JB):                1.168
# Skew:                           0.000   Prob(JB):                        0.558
# Kurtosis:                       1.816   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_Glaucoma                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     2.787
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00491
# Time:                        15:32:34   Log-Likelihood:                -228.66
# No. Observations:                 150   AIC:                             477.3
# Df Residuals:                     140   BIC:                             507.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0462      0.094     21.787      0.000       1.860       2.232
# x1            -0.1352      0.105     -1.283      0.202      -0.344       0.073
# x2            -0.0362      0.153     -0.236      0.814      -0.339       0.267
# x3             0.0003      0.229      0.001      0.999      -0.452       0.453
# x4            -0.1471      0.130     -1.130      0.260      -0.404       0.110
# x5            -0.0689      0.197     -0.350      0.727      -0.458       0.321
# x6            -0.2762      0.194     -1.421      0.158      -0.661       0.108
# x7            -0.0341      0.190     -0.180      0.857      -0.409       0.341
# x8            -0.0711      0.168     -0.424      0.672      -0.403       0.261
# x9             0.1823      0.198      0.923      0.358      -0.208       0.573
# ==============================================================================
# Omnibus:                       59.832   Durbin-Watson:                   0.760
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.444
# Skew:                           1.754   Prob(JB):                     2.35e-30
# Kurtosis:                       6.087   Cond. No.                         6.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_AMD                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.375
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     9.331
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           5.01e-11
# Time:                        15:32:34   Log-Likelihood:                -144.54
# No. Observations:                 150   AIC:                             309.1
# Df Residuals:                     140   BIC:                             339.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4695      0.054     27.417      0.000       1.364       1.576
# x1            -0.0982      0.066     -1.489      0.139      -0.229       0.032
# x2            -0.1218      0.098     -1.246      0.215      -0.315       0.072
# x3            -0.0699      0.137     -0.510      0.611      -0.341       0.201
# x4             0.0721      0.089      0.809      0.420      -0.104       0.248
# x5             0.3403      0.125      2.712      0.008       0.092       0.588
# x6            -0.4579      0.105     -4.346      0.000      -0.666      -0.250
# x7            -0.0407      0.097     -0.421      0.674      -0.232       0.150
# x8             0.3068      0.113      2.718      0.007       0.084       0.530
# x9            -0.3631      0.122     -2.983      0.003      -0.604      -0.122
# ==============================================================================
# Omnibus:                      129.251   Durbin-Watson:                   1.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1584.901
# Skew:                           3.097   Prob(JB):                         0.00
# Kurtosis:                      17.670   Cond. No.                         7.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_Cataract                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     4.098
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           0.000108
# Time:                        15:32:34   Log-Likelihood:                -156.17
# No. Observations:                 150   AIC:                             332.3
# Df Residuals:                     140   BIC:                             362.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4807      0.058     25.563      0.000       1.366       1.595
# x1            -0.0442      0.071     -0.624      0.534      -0.184       0.096
# x2            -0.0196      0.099     -0.198      0.844      -0.216       0.177
# x3            -0.2018      0.142     -1.425      0.156      -0.482       0.078
# x4             0.1428      0.086      1.660      0.099      -0.027       0.313
# x5             0.1596      0.136      1.169      0.244      -0.110       0.429
# x6            -0.3301      0.134     -2.457      0.015      -0.596      -0.064
# x7             0.0423      0.110      0.383      0.702      -0.176       0.261
# x8             0.0619      0.108      0.573      0.568      -0.152       0.276
# x9            -0.1265      0.115     -1.104      0.271      -0.353       0.100
# ==============================================================================
# Omnibus:                      116.477   Durbin-Watson:                   1.597
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1046.322
# Skew:                           2.811   Prob(JB):                    6.22e-228
# Kurtosis:                      14.653   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_Myopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     2.127
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0310
# Time:                        15:32:34   Log-Likelihood:                -162.55
# No. Observations:                 150   AIC:                             345.1
# Df Residuals:                     140   BIC:                             375.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3520      0.060     22.369      0.000       1.233       1.472
# x1            -0.0725      0.074     -0.975      0.331      -0.219       0.075
# x2             0.0259      0.099      0.263      0.793      -0.169       0.221
# x3             0.1869      0.147      1.275      0.205      -0.103       0.477
# x4             0.0159      0.104      0.153      0.879      -0.190       0.221
# x5            -0.0924      0.158     -0.586      0.559      -0.404       0.219
# x6            -0.4686      0.151     -3.105      0.002      -0.767      -0.170
# x7             0.2914      0.148      1.968      0.051      -0.001       0.584
# x8             0.0963      0.109      0.884      0.378      -0.119       0.311
# x9            -0.1996      0.125     -1.595      0.113      -0.447       0.048
# ==============================================================================
# Omnibus:                      191.167   Durbin-Watson:                   1.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6779.642
# Skew:                           5.063   Prob(JB):                         0.00
# Kurtosis:                      34.340   Cond. No.                         8.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_Presbyopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.449
# Method:                 Least Squares   F-statistic:                     14.51
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           2.09e-16
# Time:                        15:32:34   Log-Likelihood:                -20.489
# No. Observations:                 150   AIC:                             60.98
# Df Residuals:                     140   BIC:                             91.08
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2774      0.023     54.487      0.000       1.231       1.324
# x1            -0.0728      0.028     -2.567      0.011      -0.129      -0.017
# x2             0.0630      0.044      1.441      0.152      -0.023       0.150
# x3            -0.0957      0.052     -1.852      0.066      -0.198       0.006
# x4            -0.0436      0.046     -0.953      0.342      -0.134       0.047
# x5             0.0935      0.063      1.478      0.142      -0.032       0.219
# x6            -0.2205      0.041     -5.335      0.000      -0.302      -0.139
# x7            -0.0345      0.044     -0.792      0.430      -0.121       0.052
# x8             0.0592      0.044      1.341      0.182      -0.028       0.147
# x9            -0.0240      0.047     -0.511      0.610      -0.117       0.069
# ==============================================================================
# Omnibus:                       25.239   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.118
# Skew:                           0.951   Prob(JB):                     3.90e-08
# Kurtosis:                       4.357   Cond. No.                         7.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe_Normal                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     3.463
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00306
# Time:                        15:32:34   Log-Likelihood:                 18.320
# No. Observations:                  50   AIC:                            -16.64
# Df Residuals:                      40   BIC:                             2.481
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0000      0.027     37.704      0.000       0.946       1.054
# x1            -0.0533      0.046     -1.170      0.249      -0.145       0.039
# x2             0.0042      0.041      0.101      0.920      -0.079       0.087
# x3            -0.0326      0.065     -0.501      0.619      -0.164       0.099
# x4             0.0784      0.049      1.607      0.116      -0.020       0.177
# x5             0.0288      0.077      0.375      0.710      -0.127       0.184
# x6            -0.1749      0.063     -2.767      0.009      -0.303      -0.047
# x7             0.1263      0.059      2.138      0.039       0.007       0.246
# x8            -0.0049      0.054     -0.092      0.927      -0.113       0.103
# x9            -0.0727      0.061     -1.187      0.242      -0.196       0.051
# ==============================================================================
# Omnibus:                       18.371   Durbin-Watson:                   3.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.735
# Skew:                           0.822   Prob(JB):                     9.62e-12
# Kurtosis:                       7.653   Cond. No.                         9.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_Glaucoma                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     3.537
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           0.000558
# Time:                        15:32:34   Log-Likelihood:                -397.76
# No. Observations:                 150   AIC:                             815.5
# Df Residuals:                     140   BIC:                             845.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0414      0.290     10.489      0.000       2.468       3.615
# x1             0.1158      0.377      0.307      0.759      -0.630       0.861
# x2            -0.3459      0.633     -0.546      0.586      -1.597       0.906
# x3             0.2265      0.827      0.274      0.785      -1.408       1.861
# x4             1.2374      0.926      1.336      0.184      -0.594       3.069
# x5            -0.6498      0.940     -0.691      0.490      -2.508       1.208
# x6             0.7212      0.553      1.305      0.194      -0.372       1.814
# x7            -1.2070      0.582     -2.074      0.040      -2.357      -0.057
# x8             0.2746      0.402      0.684      0.495      -0.519       1.068
# x9             0.4884      0.413      1.184      0.239      -0.327       1.304
# ==============================================================================
# Omnibus:                       58.703   Durbin-Watson:                   1.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.635
# Skew:                           1.728   Prob(JB):                     2.61e-29
# Kurtosis:                       6.020   Cond. No.                         9.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_AMD                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     6.365
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           1.53e-07
# Time:                        15:32:34   Log-Likelihood:                -351.61
# No. Observations:                 150   AIC:                             723.2
# Df Residuals:                     140   BIC:                             753.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7223      0.213     12.771      0.000       2.301       3.144
# x1             1.2864      0.320      4.014      0.000       0.653       1.920
# x2            -0.2150      0.430     -0.501      0.617      -1.064       0.634
# x3            -0.5098      0.440     -1.160      0.248      -1.379       0.359
# x4             0.8588      0.537      1.599      0.112      -0.203       1.921
# x5            -0.1967      0.486     -0.405      0.686      -1.157       0.763
# x6             0.1374      0.366      0.375      0.708      -0.586       0.861
# x7            -0.7801      0.332     -2.347      0.020      -1.437      -0.123
# x8             0.2516      0.444      0.567      0.572      -0.626       1.129
# x9            -0.2547      0.387     -0.658      0.511      -1.019       0.510
# ==============================================================================
# Omnibus:                       72.443   Durbin-Watson:                   1.299
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              254.098
# Skew:                           1.879   Prob(JB):                     6.66e-56
# Kurtosis:                       8.151   Cond. No.                         8.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_Cataract                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     3.361
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           0.000933
# Time:                        15:32:34   Log-Likelihood:                -324.04
# No. Observations:                 150   AIC:                             668.1
# Df Residuals:                     140   BIC:                             698.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9333      0.177     10.900      0.000       1.583       2.284
# x1             0.1786      0.233      0.768      0.444      -0.281       0.639
# x2             0.0612      0.335      0.183      0.855      -0.601       0.724
# x3            -0.2942      0.279     -1.055      0.293      -0.846       0.257
# x4            -0.0601      0.374     -0.161      0.872      -0.799       0.678
# x5             0.6987      0.355      1.969      0.051      -0.003       1.400
# x6             0.4197      0.317      1.322      0.188      -0.208       1.047
# x7            -0.8644      0.323     -2.673      0.008      -1.504      -0.225
# x8             0.5843      0.309      1.893      0.060      -0.026       1.195
# x9            -0.2010      0.292     -0.689      0.492      -0.778       0.376
# ==============================================================================
# Omnibus:                      107.778   Durbin-Watson:                   1.376
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              693.236
# Skew:                           2.699   Prob(JB):                    2.92e-151
# Kurtosis:                      12.043   Cond. No.                         5.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_Myopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     9.501
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           3.23e-11
# Time:                        15:32:34   Log-Likelihood:                -288.60
# No. Observations:                 150   AIC:                             597.2
# Df Residuals:                     140   BIC:                             627.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8731      0.140     13.375      0.000       1.596       2.150
# x1            -0.0584      0.188     -0.312      0.756      -0.429       0.312
# x2             0.0533      0.324      0.164      0.870      -0.588       0.694
# x3            -0.9813      0.277     -3.546      0.001      -1.528      -0.434
# x4            -0.0952      0.274     -0.348      0.729      -0.636       0.446
# x5             1.4223      0.384      3.702      0.000       0.663       2.182
# x6             0.7207      0.249      2.893      0.004       0.228       1.213
# x7            -0.8419      0.233     -3.606      0.000      -1.304      -0.380
# x8            -0.4658      0.199     -2.343      0.021      -0.859      -0.073
# x9             0.7837      0.185      4.244      0.000       0.419       1.149
# ==============================================================================
# Omnibus:                       91.854   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              592.030
# Skew:                           2.166   Prob(JB):                    2.77e-129
# Kurtosis:                      11.716   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_Presbyopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     9.387
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           4.33e-11
# Time:                        15:32:34   Log-Likelihood:                -182.52
# No. Observations:                 150   AIC:                             385.0
# Df Residuals:                     140   BIC:                             415.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1809      0.069     17.103      0.000       1.044       1.317
# x1             0.0033      0.079      0.042      0.967      -0.152       0.159
# x2             0.0955      0.135      0.708      0.480      -0.171       0.362
# x3            -0.1628      0.122     -1.333      0.185      -0.404       0.079
# x4             0.0211      0.130      0.162      0.871      -0.236       0.278
# x5             0.5406      0.153      3.531      0.001       0.238       0.843
# x6             0.1248      0.097      1.284      0.201      -0.067       0.317
# x7            -0.3774      0.094     -3.994      0.000      -0.564      -0.191
# x8            -0.1635      0.114     -1.436      0.153      -0.389       0.062
# x9             0.1994      0.107      1.858      0.065      -0.013       0.412
# ==============================================================================
# Omnibus:                      120.432   Durbin-Watson:                   1.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1483.766
# Skew:                           2.781   Prob(JB):                         0.00
# Kurtosis:                      17.369   Cond. No.                         5.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice_Normal                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     3.034
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00737
# Time:                        15:32:34   Log-Likelihood:                -22.006
# No. Observations:                  50   AIC:                             64.01
# Df Residuals:                      40   BIC:                             83.13
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0000      0.059     16.832      0.000       0.880       1.120
# x1            -0.2197      0.100     -2.201      0.034      -0.422      -0.018
# x2            -0.1273      0.148     -0.862      0.394      -0.426       0.171
# x3             0.0925      0.120      0.768      0.447      -0.151       0.336
# x4             0.1903      0.160      1.191      0.241      -0.133       0.513
# x5             0.1238      0.106      1.166      0.250      -0.091       0.338
# x6             0.2482      0.135      1.839      0.073      -0.025       0.521
# x7            -0.2378      0.124     -1.921      0.062      -0.488       0.012
# x8            -0.0485      0.085     -0.571      0.571      -0.221       0.123
# x9             0.0406      0.084      0.485      0.630      -0.129       0.210
# ==============================================================================
# Omnibus:                       19.788   Durbin-Watson:                   2.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.905
# Skew:                           1.210   Prob(JB):                     7.16e-08
# Kurtosis:                       6.153   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Navigate_Glaucoma                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     2.740
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00561
# Time:                        15:32:34   Log-Likelihood:                -705.95
# No. Observations:                 150   AIC:                             1432.
# Df Residuals:                     140   BIC:                             1462.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.9129      2.263      6.149      0.000       9.439      18.386
# x1             0.6378      2.720      0.235      0.815      -4.739       6.014
# x2           -12.6952      3.338     -3.804      0.000     -19.294      -6.096
# x3            -9.3933      6.996     -1.343      0.182     -23.225       4.438
# x4            10.4956      4.483      2.341      0.021       1.633      19.359
# x5            -0.2917      6.692     -0.044      0.965     -13.521      12.938
# x6             5.3566      5.025      1.066      0.288      -4.578      15.291
# x7            -3.3966      6.332     -0.536      0.593     -15.915       9.122
# x8             0.5338      4.003      0.133      0.894      -7.379       8.447
# x9             7.6220      6.191      1.231      0.220      -4.618      19.862
# ==============================================================================
# Omnibus:                      131.839   Durbin-Watson:                   1.423
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1478.586
# Skew:                           3.244   Prob(JB):                         0.00
# Kurtosis:                      16.945   Cond. No.                         9.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Navigate_AMD                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     1.632
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.112
# Time:                        15:32:34   Log-Likelihood:                -449.98
# ...
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     1.345
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.276
# Time:                        15:32:34   Log-Likelihood:                -60.132
# No. Observations:                  30   AIC:                             140.3
# Df Residuals:                      20   BIC:                             154.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6583      0.402      6.620      0.000       1.821       3.496
# x1             0.2196      0.561      0.392      0.699      -0.950       1.389
# x2            -0.8121      1.013     -0.802      0.432      -2.926       1.301
# x3             1.0361      0.945      1.097      0.286      -0.935       3.007
# x4             0.5292      0.958      0.553      0.587      -1.468       2.527
# x5             0.1915      0.666      0.287      0.777      -1.198       1.581
# x6             1.9305      0.865      2.231      0.037       0.126       3.735
# x7            -0.7327      0.974     -0.752      0.461      -2.764       1.299
# x8            -0.6554      0.612     -1.070      0.297      -1.933       0.622
# x9            -0.6747      1.380     -0.489      0.630      -3.553       2.203
# ==============================================================================
# Omnibus:                        3.038   Durbin-Watson:                   1.190
# Prob(Omnibus):                  0.219   Jarque-Bera (JB):                2.027
# Skew:                           0.436   Prob(JB):                        0.363
# Kurtosis:                       2.072   Cond. No.                         9.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_AMD                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.9694
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.492
# Time:                        15:32:34   Log-Likelihood:                -50.642
# No. Observations:                  30   AIC:                             121.3
# Df Residuals:                      20   BIC:                             135.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2583      0.293      7.716      0.000       1.648       2.869
# x1             0.1913      0.354      0.540      0.595      -0.548       0.930
# x2            -0.1663      0.629     -0.265      0.794      -1.478       1.145
# x3             0.8139      0.924      0.881      0.389      -1.113       2.741
# x4            -0.0113      0.498     -0.023      0.982      -1.050       1.027
# x5            -0.2921      0.496     -0.589      0.563      -1.327       0.743
# x6             1.2695      0.651      1.949      0.065      -0.089       2.628
# x7            -0.7110      0.727     -0.978      0.340      -2.227       0.805
# x8            -0.0676      0.421     -0.160      0.874      -0.946       0.811
# x9            -0.7105      0.679     -1.046      0.308      -2.128       0.707
# ==============================================================================
# Omnibus:                        7.416   Durbin-Watson:                   1.471
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                5.985
# Skew:                           1.061   Prob(JB):                       0.0502
# Kurtosis:                       3.537   Cond. No.                         8.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_Cataract                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     1.220
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.337
# Time:                        15:32:34   Log-Likelihood:                -48.311
# No. Observations:                  30   AIC:                             116.6
# Df Residuals:                      20   BIC:                             130.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8250      0.271      6.740      0.000       1.260       2.390
# x1             0.0339      0.439      0.077      0.939      -0.883       0.951
# x2             0.1067      0.508      0.210      0.836      -0.952       1.166
# x3             0.2894      0.563      0.514      0.613      -0.884       1.463
# x4             0.4804      0.706      0.681      0.504      -0.991       1.952
# x5            -0.0158      0.636     -0.025      0.980      -1.342       1.310
# x6             1.2931      0.524      2.465      0.023       0.199       2.387
# x7            -0.6988      0.529     -1.321      0.202      -1.802       0.405
# x8            -0.0621      0.418     -0.149      0.883      -0.935       0.810
# x9            -0.8738      0.683     -1.279      0.216      -2.299       0.551
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   0.936
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                5.316
# Skew:                           0.949   Prob(JB):                       0.0701
# Kurtosis:                       3.806   Cond. No.                         8.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_Myopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     3.670
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00740
# Time:                        15:32:34   Log-Likelihood:                -31.256
# No. Observations:                  30   AIC:                             82.51
# Df Residuals:                      20   BIC:                             96.52
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4167      0.153      9.237      0.000       1.097       1.737
# x1            -0.1242      0.202     -0.616      0.545      -0.545       0.296
# x2            -1.1491      0.344     -3.336      0.003      -1.868      -0.430
# x3            -0.2731      0.525     -0.520      0.609      -1.369       0.823
# x4             1.8670      0.586      3.186      0.005       0.644       3.089
# x5            -0.9399      0.385     -2.443      0.024      -1.742      -0.137
# x6             0.5552      0.378      1.470      0.157      -0.233       1.343
# x7            -0.3558      0.356     -1.000      0.329      -1.098       0.386
# x8            -0.1715      0.317     -0.540      0.595      -0.834       0.491
# x9             0.6352      0.584      1.088      0.289      -0.582       1.853
# ==============================================================================
# Omnibus:                        4.240   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                2.648
# Skew:                           0.615   Prob(JB):                        0.266
# Kurtosis:                       3.779   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_Presbyopia                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     2.191
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0691
# Time:                        15:32:34   Log-Likelihood:                -17.786
# No. Observations:                  30   AIC:                             55.57
# Df Residuals:                      20   BIC:                             69.58
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0250      0.098     10.471      0.000       0.821       1.229
# x1            -0.1732      0.127     -1.367      0.187      -0.437       0.091
# x2            -0.3677      0.366     -1.005      0.327      -1.131       0.395
# x3             0.1792      0.226      0.794      0.436      -0.291       0.650
# x4             0.5338      0.288      1.857      0.078      -0.066       1.134
# x5            -0.0455      0.191     -0.238      0.814      -0.444       0.353
# x6             0.2569      0.187      1.374      0.185      -0.133       0.647
# x7             0.0423      0.211      0.200      0.843      -0.398       0.483
# x8            -0.1134      0.202     -0.562      0.581      -0.534       0.308
# x9            -0.2004      0.221     -0.908      0.375      -0.661       0.260
# ==============================================================================
# Omnibus:                        1.749   Durbin-Watson:                   2.321
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                0.661
# Skew:                           0.120   Prob(JB):                        0.718
# Kurtosis:                       3.687   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch_Normal                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):                nan
# Time:                        15:32:34   Log-Likelihood:                    inf
# No. Observations:                  10   AIC:                              -inf
# Df Residuals:                       9   BIC:                              -inf
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0000          0        inf      0.000       1.000       1.000
# x1                  0          0        nan        nan           0           0
# x2                  0          0        nan        nan           0           0
# x3                  0          0        nan        nan           0           0
# x4                  0          0        nan        nan           0           0
# x5                  0          0        nan        nan           0           0
# x6                  0          0        nan        nan           0           0
# x7                  0          0        nan        nan           0           0
# x8                  0          0        nan        nan           0           0
# x9                  0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
#
#
#
#
#
#
#
# nan
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\statsmodels\regression\linear_model.py:1752: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\statsmodels\regression\linear_model.py:940: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# c:\Users\capri28\mambaforge\envs\igvi\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)

# %% [markdown]
# ### Aggregate across VIs

# %%
rsq = []
models = {task: None for task in tasks_re}
for task in tasks_re:
    x, y, groups = [], [], []
    for vi in ori_vis[:-1]:
        for id in ids:
            for trial in range(len(redv[dv][task][vi][id])):
                x.append([redv[dv][task][vi][id][trial] for dv in redv])
            groups.extend([id] * len(redv[dv][task][vi][id]))
    y = np.hstack([np.array([reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] for id in ids]).flatten() for vi in ori_vis[:-1]])
    x = np.array(x)
    x = add_constant(x)
    groups = np.array(groups).flatten()
    # outlier removal
    if outlier_removal:
        mask = np.abs(y - np.mean(y)) < 2 * np.std(y)
        x = x[mask]
        y = y[mask]
        groups = groups[mask]
    models[task] = OLS(y, x, missing='drop').fit()
    rsq.append(models[task].rsquared_adj)
    print(task, models[task].summary(), "\n" * 10)
print(np.mean(rsq))
# Out:
# Place                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.6727
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.734
# Time:                        15:32:34   Log-Likelihood:                -564.46
# No. Observations:                 300   AIC:                             1149.
# Df Residuals:                     290   BIC:                             1186.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9341      0.093     20.739      0.000       1.751       2.118
# x1            -0.1103      0.106     -1.038      0.300      -0.319       0.099
# x2             0.0451      0.150      0.300      0.764      -0.251       0.341
# x3             0.1054      0.225      0.468      0.640      -0.338       0.548
# x4             0.0184      0.164      0.112      0.911      -0.305       0.341
# x5            -0.0353      0.233     -0.152      0.880      -0.494       0.423
# x6            -0.3205      0.181     -1.768      0.078      -0.677       0.036
# x7             0.1513      0.177      0.854      0.394      -0.197       0.500
# x8             0.0266      0.116      0.230      0.818      -0.201       0.254
# x9             0.0151      0.167      0.090      0.928      -0.314       0.345
# ==============================================================================
# Omnibus:                      123.515   Durbin-Watson:                   0.688
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              333.854
# Skew:                           1.985   Prob(JB):                     3.20e-73
# Kurtosis:                       6.308   Cond. No.                         7.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Wipe                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     13.85
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           9.91e-21
# Time:                        15:32:34   Log-Likelihood:                -902.03
# No. Observations:                 750   AIC:                             1824.
# Df Residuals:                     740   BIC:                             1870.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5252      0.030     51.504      0.000       1.467       1.583
# x1            -0.0922      0.034     -2.727      0.007      -0.159      -0.026
# x2             0.0033      0.048      0.068      0.945      -0.091       0.098
# x3            -0.0766      0.068     -1.120      0.263      -0.211       0.058
# x4            -0.0086      0.045     -0.190      0.849      -0.097       0.080
# x5             0.1247      0.068      1.834      0.067      -0.009       0.258
# x6            -0.3030      0.060     -5.091      0.000      -0.420      -0.186
# x7             0.0034      0.056      0.060      0.952      -0.107       0.114
# x8             0.0828      0.053      1.559      0.119      -0.021       0.187
# x9            -0.0943      0.059     -1.606      0.109      -0.210       0.021
# ==============================================================================
# Omnibus:                      561.395   Durbin-Watson:                   1.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7692.705
# Skew:                           3.369   Prob(JB):                         0.00
# Kurtosis:                      17.169   Cond. No.                         7.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Slice                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     15.72
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           1.15e-23
# Time:                        15:32:34   Log-Likelihood:                -1743.5
# No. Observations:                 750   AIC:                             3507.
# Df Residuals:                     740   BIC:                             3553.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1502      0.091     23.645      0.000       1.972       2.329
# x1             0.3180      0.112      2.838      0.005       0.098       0.538
# x2            -0.0754      0.170     -0.443      0.658      -0.410       0.259
# x3            -0.2997      0.166     -1.801      0.072      -0.627       0.027
# x4             0.2553      0.186      1.370      0.171      -0.110       0.621
# x5             0.3574      0.203      1.756      0.079      -0.042       0.757
# x6             0.4238      0.144      2.952      0.003       0.142       0.706
# x7            -0.7607      0.144     -5.290      0.000      -1.043      -0.478
# x8             0.0457      0.134      0.341      0.733      -0.217       0.308
# x9             0.4127      0.131      3.149      0.002       0.155       0.670
# ==============================================================================
# Omnibus:                      479.401   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4414.750
# Skew:                           2.856   Prob(JB):                         0.00
# Kurtosis:                      13.423   Cond. No.                         5.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Navigate                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     2.940
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):            0.00195
# Time:                        15:32:34   Log-Likelihood:                -3074.4
# No. Observations:                 750   AIC:                             6169.
# Df Residuals:                     740   BIC:                             6215.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.2766      0.536      9.839      0.000       4.224       6.329
# x1            -0.9576      0.648     -1.478      0.140      -2.229       0.314
# x2            -3.2830      0.797     -4.119      0.000      -4.848      -1.718
# x3            -3.1694      1.710     -1.853      0.064      -6.527       0.188
# x4             1.6525      1.098      1.504      0.133      -0.504       3.809
# x5             1.9109      1.581      1.209      0.227      -1.192       5.014
# x6             0.8931      1.157      0.772      0.440      -1.378       3.164
# x7             0.1363      1.511      0.090      0.928      -2.830       3.103
# x8             0.5322      0.906      0.587      0.557      -1.247       2.311
# x9             0.9707      1.400      0.694      0.488      -1.777       3.718
# ==============================================================================
# Omnibus:                      995.724   Durbin-Watson:                   1.326
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           140692.388
# Skew:                           7.021   Prob(JB):                         0.00
# Kurtosis:                      68.612   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Throw                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     6.709
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           1.81e-09
# Time:                        15:32:34   Log-Likelihood:                -2590.4
# No. Observations:                1500   AIC:                             5201.
# Df Residuals:                    1490   BIC:                             5254.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.1697      0.035    -33.181      0.000      -1.239      -1.101
# x1             0.0750      0.039      1.901      0.058      -0.002       0.152
# x2             0.0215      0.046      0.463      0.644      -0.069       0.112
# x3             0.1085      0.074      1.470      0.142      -0.036       0.253
# x4             0.2778      0.065      4.261      0.000       0.150       0.406
# x5            -0.3090      0.072     -4.281      0.000      -0.451      -0.167
# x6            -0.4660      0.079     -5.871      0.000      -0.622      -0.310
# x7             0.2830      0.064      4.407      0.000       0.157       0.409
# x8             0.0389      0.042      0.919      0.358      -0.044       0.122
# x9            -0.0135      0.051     -0.266      0.790      -0.113       0.086
# ==============================================================================
# Omnibus:                    17398.938   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.144
# Skew:                          -0.444   Prob(JB):                     4.16e-38
# Kurtosis:                       1.598   Cond. No.                         6.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# Catch                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     4.203
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           7.92e-05
# Time:                        15:32:34   Log-Likelihood:                -267.85
# No. Observations:                 150   AIC:                             555.7
# Df Residuals:                     140   BIC:                             585.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8367      0.122     15.060      0.000       1.596       2.078
# x1             0.0209      0.135      0.155      0.877      -0.246       0.288
# x2            -0.3068      0.215     -1.424      0.157      -0.733       0.119
# x3             0.4895      0.240      2.043      0.043       0.016       0.963
# x4             0.4356      0.241      1.807      0.073      -0.041       0.912
# x5            -0.1592      0.204     -0.781      0.436      -0.562       0.244
# x6             1.0420      0.229      4.542      0.000       0.588       1.496
# x7            -0.4269      0.231     -1.850      0.066      -0.883       0.029
# x8            -0.0330      0.164     -0.202      0.840      -0.356       0.290
# x9            -0.5324      0.275     -1.933      0.055      -1.077       0.012
# ==============================================================================
# Omnibus:                       58.551   Durbin-Watson:                   1.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              145.469
# Skew:                           1.645   Prob(JB):                     2.58e-32
# Kurtosis:                       6.528   Cond. No.                         5.99
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# 0.08202247025897456

# %% [markdown]
# ### Aggregate across tasks

# %%
task_weights = {
    "Place": 28/2,
    "Wipe": 28/5,
    "Slice": 28/5,
    "Navigate": 28/5,
    "Throw": 28/10,
    "Catch": 28/1,
}
models = {vi: None for vi in vis}
rsq = []
for vi in ori_vis[:-1]:
    x, y, groups, weights = [], [], [], []
    for task in tasks_re:
        for id in ids:
            for trial in range(len(redv[dv][task][vi][id])):
                x.append([redv[dv][task][vi][id][trial] for dv in redv])
            groups.extend([id] * len(redv[dv][task][vi][id]))
            weights.extend([task_weights[task]] * len(redv[dv][task][vi][id]))
    y = np.hstack([np.array([reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] for id in ids]).flatten() for task in tasks_re])
    x = np.array(x)
    x = add_constant(x)
    groups = np.array(groups).flatten()
    weights = np.array(weights).flatten()
    # outlier removal
    if outlier_removal:
        mask = np.abs(y - np.mean(y)) < 2 * np.std(y)
        x = x[mask]
        y = y[mask]
        groups = groups[mask]
        weights = np.array(weights)[mask]
    models[vi] = WLS(y, x, weights, missing='drop').fit()
    rsq.append(models[vi].rsquared_adj)
    print(vi, models[vi].summary(), "\n" * 10)
print(np.mean(rsq))
# Out:
# cataract_1                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.045
# Model:                            WLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.406
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.185
# Time:                        16:54:29   Log-Likelihood:                -623.70
# No. Observations:                 280   AIC:                             1267.
# Df Residuals:                     270   BIC:                             1304.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1348      0.124      9.151      0.000       0.891       1.379
# x1            -0.1120      0.137     -0.820      0.413      -0.381       0.157
# x2            -0.1002      0.178     -0.563      0.574      -0.451       0.250
# x3             0.1100      0.218      0.504      0.615      -0.320       0.540
# x4             0.1810      0.197      0.920      0.358      -0.206       0.568
# x5            -0.0905      0.234     -0.386      0.700      -0.552       0.371
# x6            -0.1305      0.216     -0.605      0.546      -0.555       0.294
# x7             0.0038      0.215      0.018      0.986      -0.420       0.428
# x8             0.4951      0.166      2.974      0.003       0.167       0.823
# x9            -0.2426      0.191     -1.271      0.205      -0.618       0.133
# ==============================================================================
# Omnibus:                      228.821   Durbin-Watson:                   1.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5447.668
# Skew:                           3.079   Prob(JB):                         0.00
# Kurtosis:                      23.713   Cond. No.                         4.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# cataract_2                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            WLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.5177
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.861
# Time:                        16:54:29   Log-Likelihood:                -756.33
# No. Observations:                 280   AIC:                             1533.
# Df Residuals:                     270   BIC:                             1569.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2501      0.199      6.277      0.000       0.858       1.642
# x1            -0.1511      0.230     -0.658      0.511      -0.603       0.301
# x2            -0.0667      0.374     -0.178      0.859      -0.803       0.670
# x3            -0.5336      0.461     -1.158      0.248      -1.441       0.374
# x4             0.1095      0.452      0.242      0.809      -0.780       0.999
# x5             0.5391      0.498      1.081      0.280      -0.442       1.521
# x6            -0.4492      0.433     -1.038      0.300      -1.301       0.403
# x7             0.1335      0.429      0.311      0.756      -0.712       0.979
# x8            -0.0319      0.278     -0.115      0.909      -0.579       0.515
# x9             0.3696      0.346      1.070      0.286      -0.311       1.050
# ==============================================================================
# Omnibus:                      397.414   Durbin-Watson:                   1.362
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51931.939
# Skew:                           6.738   Prob(JB):                         0.00
# Kurtosis:                      68.343   Cond. No.                         7.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# cataract_3                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            WLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5916
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.804
# Time:                        16:54:29   Log-Likelihood:                -907.49
# No. Observations:                 280   AIC:                             1835.
# Df Residuals:                     270   BIC:                             1871.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3928      0.342      7.003      0.000       1.720       3.065
# x1            -0.1096      0.366     -0.299      0.765      -0.831       0.612
# x2             0.3978      0.526      0.757      0.450      -0.637       1.433
# x3            -1.1424      0.647     -1.767      0.078      -2.415       0.131
# x4            -0.1295      0.527     -0.245      0.806      -1.168       0.909
# x5             0.3511      0.639      0.550      0.583      -0.906       1.609
# x6             0.5647      0.577      0.978      0.329      -0.572       1.701
# x7            -0.5690      0.616     -0.924      0.356      -1.781       0.643
# x8            -0.0076      0.494     -0.015      0.988      -0.980       0.965
# x9             0.1968      0.576      0.342      0.733      -0.937       1.331
# ==============================================================================
# Omnibus:                      468.245   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           133347.611
# Skew:                           8.887   Prob(JB):                         0.00
# Kurtosis:                     108.422   Cond. No.                         5.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# amd_1                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.018
# Model:                            WLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5613
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.828
# Time:                        16:54:29   Log-Likelihood:                -678.98
# No. Observations:                 280   AIC:                             1378.
# Df Residuals:                     270   BIC:                             1414.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0483      0.151      6.939      0.000       0.751       1.346
# x1            -0.0756      0.162     -0.468      0.640      -0.394       0.242
# x2            -0.3843      0.280     -1.373      0.171      -0.935       0.167
# x3            -0.0614      0.355     -0.173      0.863      -0.761       0.638
# x4             0.4758      0.302      1.575      0.116      -0.119       1.070
# x5             0.1897      0.393      0.483      0.630      -0.584       0.963
# x6            -0.1153      0.286     -0.403      0.687      -0.679       0.448
# x7            -0.1252      0.296     -0.423      0.673      -0.708       0.458
# x8             0.0815      0.203      0.402      0.688      -0.318       0.481
# x9            -0.0259      0.272     -0.095      0.924      -0.562       0.510
# ==============================================================================
# Omnibus:                      308.536   Durbin-Watson:                   1.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13722.088
# Skew:                           4.670   Prob(JB):                         0.00
# Kurtosis:                      35.999   Cond. No.                         7.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# amd_2                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.024
# Model:                            WLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.7241
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.687
# Time:                        16:54:29   Log-Likelihood:                -734.08
# No. Observations:                 280   AIC:                             1488.
# Df Residuals:                     270   BIC:                             1524.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6723      0.184      9.092      0.000       1.310       2.034
# x1             0.0287      0.219      0.131      0.896      -0.402       0.460
# x2            -0.0601      0.287     -0.210      0.834      -0.625       0.505
# x3            -0.2422      0.336     -0.720      0.472      -0.904       0.420
# x4             0.1939      0.317      0.612      0.541      -0.430       0.818
# x5             0.1881      0.344      0.547      0.585      -0.489       0.865
# x6            -0.2184      0.346     -0.632      0.528      -0.899       0.462
# x7            -0.2688      0.335     -0.803      0.423      -0.928       0.391
# x8             0.2050      0.234      0.874      0.383      -0.257       0.667
# x9             0.1233      0.271      0.455      0.649      -0.410       0.656
# ==============================================================================
# Omnibus:                      224.041   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2786.013
# Skew:                           3.294   Prob(JB):                         0.00
# Kurtosis:                      16.978   Cond. No.                         5.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# amd_3                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.032
# Model:                            WLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9908
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.448
# Time:                        16:54:29   Log-Likelihood:                -763.68
# No. Observations:                 280   AIC:                             1547.
# Df Residuals:                     270   BIC:                             1584.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8917      0.204     14.146      0.000       2.489       3.294
# x1             0.2904      0.234      1.243      0.215      -0.170       0.750
# x2            -0.2186      0.314     -0.696      0.487      -0.837       0.400
# x3            -0.2044      0.366     -0.558      0.577      -0.926       0.517
# x4             0.4042      0.324      1.246      0.214      -0.234       1.043
# x5            -0.1378      0.373     -0.370      0.712      -0.872       0.596
# x6             0.3568      0.348      1.026      0.306      -0.328       1.042
# x7            -0.5047      0.350     -1.442      0.151      -1.194       0.184
# x8             0.1174      0.262      0.448      0.655      -0.399       0.634
# x9             0.0534      0.278      0.192      0.848      -0.494       0.601
# ==============================================================================
# Omnibus:                      150.179   Durbin-Watson:                   1.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              772.352
# Skew:                           2.243   Prob(JB):                    1.93e-168
# Kurtosis:                       9.788   Cond. No.                         5.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# glaucoma_1                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.027
# Model:                            WLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8376
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.582
# Time:                        16:54:29   Log-Likelihood:                -820.63
# No. Observations:                 280   AIC:                             1661.
# Df Residuals:                     270   BIC:                             1698.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2427      0.251      4.960      0.000       0.749       1.736
# x1             0.3160      0.260      1.213      0.226      -0.197       0.829
# x2            -0.6788      0.405     -1.677      0.095      -1.476       0.118
# x3            -0.0625      0.550     -0.114      0.910      -1.145       1.020
# x4             0.5552      0.410      1.353      0.177      -0.253       1.363
# x5             0.0851      0.551      0.154      0.877      -1.000       1.170
# x6            -0.0543      0.470     -0.116      0.908      -0.980       0.871
# x7            -0.2058      0.468     -0.440      0.661      -1.127       0.716
# x8            -0.2289      0.351     -0.653      0.514      -0.919       0.461
# x9             0.1390      0.409      0.340      0.734      -0.665       0.944
# ==============================================================================
# Omnibus:                      470.418   Durbin-Watson:                   1.309
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           127064.529
# Skew:                           9.007   Prob(JB):                         0.00
# Kurtosis:                     105.794   Cond. No.                         6.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# glaucoma_2                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.034
# Model:                            WLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.043
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.406
# Time:                        16:54:29   Log-Likelihood:                -860.16
# No. Observations:                 280   AIC:                             1740.
# Df Residuals:                     270   BIC:                             1777.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0247      0.289      7.017      0.000       1.457       2.593
# x1             0.0084      0.319      0.026      0.979      -0.620       0.636
# x2            -0.8675      0.466     -1.862      0.064      -1.785       0.050
# x3            -0.2031      0.552     -0.368      0.713      -1.290       0.884
# x4            -0.3265      0.514     -0.635      0.526      -1.338       0.686
# x5             0.7099      0.590      1.204      0.230      -0.451       1.871
# x6             0.3997      0.528      0.757      0.450      -0.640       1.439
# x7            -0.3195      0.518     -0.617      0.538      -1.339       0.700
# x8            -0.0600      0.430     -0.140      0.889      -0.907       0.787
# x9             0.4128      0.488      0.847      0.398      -0.547       1.373
# ==============================================================================
# Omnibus:                      348.430   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21487.263
# Skew:                           5.616   Prob(JB):                         0.00
# Kurtosis:                      44.420   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# glaucoma_3                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.059
# Model:                            WLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     1.866
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0571
# Time:                        16:54:29   Log-Likelihood:                -1265.4
# No. Observations:                 280   AIC:                             2551.
# Df Residuals:                     270   BIC:                             2587.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.1112      1.227      6.612      0.000       5.696      10.527
# x1             1.2604      1.321      0.954      0.341      -1.340       3.860
# x2            -6.1161      1.850     -3.307      0.001      -9.758      -2.475
# x3             0.3921      2.546      0.154      0.878      -4.620       5.404
# x4             4.6465      1.944      2.390      0.018       0.819       8.474
# x5            -1.2913      2.404     -0.537      0.592      -6.024       3.441
# x6            -1.1702      2.424     -0.483      0.630      -5.943       3.603
# x7             0.5927      2.574      0.230      0.818      -4.474       5.660
# x8             1.4176      1.587      0.893      0.372      -1.706       4.542
# x9             1.4797      1.910      0.775      0.439      -2.282       5.241
# ==============================================================================
# Omnibus:                      329.063   Durbin-Watson:                   1.255
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14365.485
# Skew:                           5.247   Prob(JB):                         0.00
# Kurtosis:                      36.484   Cond. No.                         6.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# presbyopia_1                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.022
# Model:                            WLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.6616
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.743
# Time:                        16:54:29   Log-Likelihood:                -614.86
# No. Observations:                 280   AIC:                             1250.
# Df Residuals:                     270   BIC:                             1286.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9651      0.120      8.033      0.000       0.729       1.202
# x1             0.1398      0.148      0.948      0.344      -0.151       0.430
# x2             0.1013      0.179      0.567      0.571      -0.250       0.453
# x3             0.0703      0.240      0.292      0.770      -0.403       0.544
# x4            -0.0618      0.221     -0.279      0.780      -0.498       0.374
# x5            -0.1974      0.293     -0.673      0.501      -0.775       0.380
# x6            -0.0719      0.213     -0.337      0.736      -0.492       0.348
# x7            -0.2334      0.209     -1.117      0.265      -0.645       0.178
# x8            -0.0844      0.203     -0.416      0.678      -0.484       0.315
# x9             0.1861      0.239      0.779      0.436      -0.284       0.656
# ==============================================================================
# Omnibus:                      344.908   Durbin-Watson:                   1.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33816.713
# Skew:                           5.264   Prob(JB):                         0.00
# Kurtosis:                      55.799   Cond. No.                         6.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# presbyopia_2                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.018
# Model:                            WLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5574
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.831
# Time:                        16:54:29   Log-Likelihood:                -636.99
# No. Observations:                 280   AIC:                             1294.
# Df Residuals:                     270   BIC:                             1330.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8680      0.130      6.676      0.000       0.612       1.124
# x1            -0.1830      0.147     -1.244      0.215      -0.473       0.107
# x2             0.0552      0.195      0.283      0.777      -0.328       0.439
# x3            -0.1506      0.236     -0.637      0.524      -0.616       0.315
# x4             0.0419      0.223      0.188      0.851      -0.397       0.481
# x5             0.2060      0.253      0.814      0.416      -0.292       0.704
# x6            -0.2712      0.227     -1.196      0.233      -0.717       0.175
# x7             0.0820      0.234      0.350      0.727      -0.380       0.544
# x8            -0.1961      0.170     -1.150      0.251      -0.532       0.140
# x9             0.0789      0.192      0.411      0.681      -0.299       0.457
# ==============================================================================
# Omnibus:                      411.285   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            76560.929
# Skew:                           7.010   Prob(JB):                         0.00
# Kurtosis:                      82.786   Cond. No.                         5.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# presbyopia_3                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            WLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.5286
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.853
# Time:                        16:54:29   Log-Likelihood:                -681.24
# No. Observations:                 280   AIC:                             1382.
# Df Residuals:                     270   BIC:                             1419.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0169      0.152      6.677      0.000       0.717       1.317
# x1            -0.1864      0.180     -1.036      0.301      -0.541       0.168
# x2            -0.0589      0.215     -0.274      0.784      -0.481       0.363
# x3             0.2448      0.256      0.954      0.341      -0.260       0.750
# x4            -0.0821      0.256     -0.321      0.749      -0.586       0.421
# x5             0.2636      0.306      0.862      0.390      -0.339       0.866
# x6            -0.1274      0.218     -0.584      0.560      -0.557       0.302
# x7            -0.1003      0.233     -0.431      0.666      -0.558       0.357
# x8            -0.1348      0.221     -0.609      0.543      -0.571       0.301
# x9             0.0319      0.268      0.119      0.905      -0.495       0.559
# ==============================================================================
# Omnibus:                      381.373   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42505.255
# Skew:                           6.302   Prob(JB):                         0.00
# Kurtosis:                      62.029   Cond. No.                         5.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# myopia_1                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.059
# Model:                            WLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.896
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):             0.0526
# Time:                        16:54:29   Log-Likelihood:                -549.05
# No. Observations:                 280   AIC:                             1118.
# Df Residuals:                     270   BIC:                             1154.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8946      0.095      9.419      0.000       0.708       1.082
# x1            -0.2860      0.105     -2.714      0.007      -0.493      -0.079
# x2            -0.2117      0.136     -1.560      0.120      -0.479       0.055
# x3             0.3742      0.200      1.870      0.063      -0.020       0.768
# x4             0.0300      0.190      0.158      0.875      -0.344       0.404
# x5            -0.1496      0.227     -0.659      0.510      -0.596       0.297
# x6            -0.1043      0.184     -0.568      0.571      -0.466       0.257
# x7            -0.0192      0.182     -0.105      0.916      -0.377       0.339
# x8             0.1073      0.137      0.781      0.435      -0.163       0.378
# x9             0.1540      0.165      0.932      0.352      -0.171       0.480
# ==============================================================================
# Omnibus:                       66.647   Durbin-Watson:                   1.178
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.714
# Skew:                           1.033   Prob(JB):                     2.60e-44
# Kurtosis:                       6.596   Cond. No.                         6.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# myopia_2                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            WLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6283
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.773
# Time:                        16:54:29   Log-Likelihood:                -842.87
# No. Observations:                 280   AIC:                             1706.
# Df Residuals:                     270   BIC:                             1742.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5218      0.271      5.610      0.000       0.988       2.056
# x1            -0.0793      0.327     -0.243      0.808      -0.723       0.564
# x2            -0.0951      0.431     -0.221      0.825      -0.943       0.753
# x3            -0.6482      0.591     -1.097      0.274      -1.812       0.515
# x4            -0.4850      0.454     -1.067      0.287      -1.380       0.410
# x5             0.9300      0.660      1.410      0.160      -0.369       2.229
# x6             0.7098      0.528      1.345      0.180      -0.329       1.749
# x7            -0.5110      0.553     -0.925      0.356      -1.599       0.577
# x8            -0.2937      0.348     -0.844      0.400      -0.979       0.392
# x9             0.2091      0.434      0.482      0.630      -0.645       1.064
# ==============================================================================
# Omnibus:                      453.223   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           101017.948
# Skew:                           8.441   Prob(JB):                         0.00
# Kurtosis:                      94.508   Cond. No.                         6.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# myopia_3                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.029
# Model:                            WLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8965
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):              0.529
# Time:                        16:54:29   Log-Likelihood:                -754.36
# No. Observations:                 280   AIC:                             1529.
# Df Residuals:                     270   BIC:                             1565.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8477      0.198      9.344      0.000       1.458       2.237
# x1            -0.2345      0.209     -1.124      0.262      -0.645       0.176
# x2            -0.5229      0.314     -1.663      0.097      -1.142       0.096
# x3            -0.1294      0.427     -0.303      0.762      -0.970       0.711
# x4             0.1922      0.358      0.537      0.592      -0.513       0.897
# x5             0.1484      0.482      0.308      0.758      -0.801       1.098
# x6             0.6514      0.335      1.945      0.053      -0.008       1.311
# x7            -0.4461      0.350     -1.274      0.204      -1.135       0.243
# x8            -0.0624      0.268     -0.233      0.816      -0.590       0.466
# x9             0.3231      0.316      1.023      0.307      -0.299       0.945
# ==============================================================================
# Omnibus:                      271.947   Durbin-Watson:                   1.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6424.773
# Skew:                           4.070   Prob(JB):                         0.00
# Kurtosis:                      25.010   Cond. No.                         6.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#
#
#
#
#
#
# -0.0029934383697551416

# %% [markdown]
# ### Aggregate across all

# %%
rsq = []
x, y, groups, weights = [], [], [], []
for vi in ori_vis[:-1]:
    for task in tasks_re:
        for id in ids:
            for trial in range(len(redv[dv][task][vi][id])):
                x.append([redv[dv][task][vi][id][trial] for dv in redv])
            groups.extend([id] * len(redv[dv][task][vi][id]))
            weights.extend([task_weights[task]] * len(redv[dv][task][vi][id]))
    y.append(np.hstack([np.array([reiv[tasks_dv1[task]][f"{task.lower()}_{vi}"][id] for id in ids]).flatten() for task in tasks_re]))
x = np.array(x)
x = add_constant(x)
y = np.array(y).flatten()
groups = np.array(groups).flatten()
weights = np.array(weights).flatten()
# outlier removal
if outlier_removal:
    mask = np.abs(y - np.mean(y)) < 2 * np.std(y)
    x = x[mask]
    y = y[mask]
    groups = groups[mask]
    weights = np.array(weights)[mask]
model = WLS(y, x, weights, missing='drop').fit()
print("All", model.summary())
# Out:
# All                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            WLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.210
# Date:                Wed, 01 Feb 2023   Prob (F-statistic):           0.000696
# Time:                        16:54:20   Log-Likelihood:                -14239.
# No. Observations:                4200   AIC:                         2.850e+04
# Df Residuals:                    4190   BIC:                         2.856e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9255      0.101     19.122      0.000       1.728       2.123
# x1            -0.0038      0.109     -0.035      0.972      -0.218       0.210
# x2            -0.6290      0.150     -4.191      0.000      -0.923      -0.335
# x3            -0.1988      0.191     -1.038      0.299      -0.574       0.176
# x4             0.4180      0.168      2.484      0.013       0.088       0.748
# x5             0.1886      0.204      0.925      0.355      -0.211       0.588
# x6             0.1116      0.175      0.637      0.524      -0.232       0.455
# x7            -0.2502      0.178     -1.403      0.161      -0.600       0.099
# x8             0.1237      0.133      0.933      0.351      -0.136       0.384
# x9             0.1795      0.158      1.136      0.256      -0.130       0.489
# ==============================================================================
# Omnibus:                     8103.117   Durbin-Watson:                   1.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17562982.982
# Skew:                          14.950   Prob(JB):                         0.00
# Kurtosis:                     318.382   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
